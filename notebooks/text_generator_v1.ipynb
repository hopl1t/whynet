# %%
# !pip install -U torchtext==0.8.0
# Out:
# Requirement already up-to-date: torchtext==0.8.0 in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.8.0) (4.41.1)
# Requirement already satisfied, skipping upgrade: torch in /usr/local/lib/python3.7/dist-packages (from torchtext==0.8.0) (1.7.1+cu101)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.8.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.8.0) (2.23.0)
# Requirement already satisfied, skipping upgrade: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext==0.8.0) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.8.0) (2020.12.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.8.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.8.0) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.8.0) (1.24.3)

# %%
# !nvidia-smi
# Out:
# Tue Mar  2 21:00:19 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    46W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer
import io
import os
import random
import torch
from torchtext.utils import download_from_url, extract_archive
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
import time
import re
import fileinput
import pickle
import time
from torchtext import datasets
import torchtext
import torchvision.transforms as transforms
import pandas as pd
from torch.utils.data import TensorDataset, random_split
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('drive/MyDrive/Colab Notebooks/nn_project')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PICKLE_PATH = 'data/ynet_data.pkl'
MAX_LEN = 512
# Back Propogation Through Time
BPTT = 512
BATCH_SIZE = 12
EVAL_BATCH_SIZE = 6
EOS = '[EOS]'
SPECIAL_TOKENS = ['[SOS]', '[SUB]', '[EOS]', '[SEC]', '[UNK]'\
                  '[PAD]', '[UNK]', '[SEP]', '[SEP1]', '[SEP2]']
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def char_tokenizer(text, special_tokens = SPECIAL_TOKENS):
    """
    TODO: ignore special chars - decrease vocab size
    Generator
    tokenizes text to chars, expcet for special tokens
    """
    for word in text.split():
        if word in special_tokens:
            yield word
        else:
            for char in word:
                yield char
            yield ' '

class PositionalEncoding(nn.Module):
    """
    Injects some information about the relative or absolute position of the
    tokens in the sequence. The positional encodings have the same dimension as
    the embeddings so that the two can be summed. Here, we use sine and cosine 
    functions of different frequencies.
    """
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        # pe = positional encoding. Buffer = data that is not a model parameter but kept anyway
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)            

class TransformerModel(nn.Module):
    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5,\
                 num_meta=2, num_classes=12, min_time=1, max_time=2203):
        """
        Encoder only transformer (like Bert)
        :param ntoken - int: size of the dictionary of embeddings (num_embeddings)
        :param ninp: the number of expected features in the input (d_model)
        :param nhead: the number of heads in the multiheadattention models
        :param nhid: the dimension of the feedforward network model (torch default 2048)
        :param nlayers: number of encoder layers
        :param dropout: float, probability for dropout of a neuron
        """
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.pos_encoder = PositionalEncoding(ninp - num_meta, dropout)
        self.num_classes = num_classes
        self.min_time = min_time
        self.max_time = max_time
        # self-attn and feedforward network.
        # This standard encoder layer is based on the paper "Attention Is All You Need".
        # This has multiheaded_attention + add&norm + pointwise feed_forward (entire left encoder part)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        
        # TransformerEncoder is a stack of N encoder layers
        # This is the encoder only alot of stack for better encoding - this is the actual layer used
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        
        # A simple lookup table that stores embeddings of a fixed dictionary and size
        self.encoder = nn.Embedding(ntoken, ninp - num_meta) # -2 because we add two meta entries manually
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)
        self.init_weights()

    def generate_square_subsequent_mask(self, sz):
        """
        A square attention mask is required because the self-attention layers 
        in nn.TransformerEncoder are only allowed to attend the earlier 
        positions in the sequence. For the language modeling task, any tokens on
        the future positions should be masked.
        :param sz - : size?
        """
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, data, src_mask):
        # Embedding
        src = data[:,:,0] # these are the letter tokens
        meta1 = data[:,:,1]  / self.num_classes # labels, scaled down by num classes
        # timestamp + min-max normalization
        meta2 = (data[:,:,2] - self.min_time) / (self.max_time - self.min_time) 
        src = self.encoder(src) * math.sqrt(self.ninp)
        # Injects some information about the relative or absolute position of the tokens in the sequence
        src = self.pos_encoder(src)
        # Concat meta data as two single entries in the embedded state (no pos embedding)
        src = torch.cat((src, meta1.unsqueeze(2)), 2)
        
        # TODO!!!

        # meta1 = F.one_hot(meta1, self.num_classes) 
        # meta1 = self.encode_meta1(meta1) should yield 5
        # meta2 = self.encode_meta1(meta2) should yield 5
        # Also change embeding dims for rest of net
        src = torch.cat((src, meta2.unsqueeze(2)), 2)
        # multi-head transformer
        output = self.transformer_encoder(src, src_mask)
        # fully connected linear
        output = self.decoder(output)
        return output

def data_process(data_iter, meta1_iter, meta2_iter):
    """
    Processes data and 2 metadata fileds
    First two entries for each item will be the meta entries (needs to be split in forward logic)
    """
    processed = torch.zeros((len(data_iter), MAX_LEN, 3), dtype=torch.long)
    for idx, (string, meta1, meta2) in enumerate(zip(data_iter, meta1_iter, meta2_iter)):
        tokenized = [vocab[token] for token in tokenizer(string)]
        if len(tokenized) < MAX_LEN:
            tokenized += ([vocab.stoi['[PAD]']] * (MAX_LEN - len(tokenized)))
        processed[idx][:,0] = torch.tensor(tokenized, dtype=torch.long)
        processed[idx][:,1] = torch.tensor(meta1, dtype=torch.long)
        processed[idx][:,2] = torch.tensor(meta2, dtype=torch.long)
        
    return torch.cat(tuple(filter(lambda t: t.numel() > 0, processed)))

def batchify(data, bsz):
    # Divide the dataset into bsz parts. (bsz = batch size)
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
#     data = data.view(bsz, -1).t().contiguous()
    data = torch.transpose(data.view(bsz, -1, 3), 0, 1).contiguous()
#     yield data.to(device)
    return data.to(device)

def get_batch(source, i):
    """
    Generates the input and target sequence for the transformer model. 
    It subdivides the source data into chunks of length BPTT. 
    For the language modeling task, the model needs the following words 
    as Target.
    """
    seq_len = min(BPTT, len(source) - 1 - i)
    data = source[i:i+seq_len]
    # this is a good fix, even for alter when we use style transfer.
    target = source[i+1:i+1+seq_len].reshape(-1)[::3]
    return data, target

def train():
    """
    Trains one epoch - stochastic GD over an entire batch
    StepLR is applied to adjust the learn rate through epochs. 
    During the training, we use nn.utils.clip_grad_norm_ function to scale 
    all the gradient together to prevent exploding.
    """
    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()
    # A square attention mask is required because the self-attention layers 
    # in nn.TransformerEncoder are only allowed to attend the earlier 
    # positions in the sequence.
    src_mask = model.generate_square_subsequent_mask(BPTT).to(device)
    for batch, i in enumerate(range(0, train_data_post.size(0) - 1, BPTT)):
        data, targets = get_batch(train_data_post, i)
        optimizer.zero_grad()
        # source data into chunks of length BPTT
        if data.size(0) != BPTT:
            # src_mask = model.generate_square_subsequent_mask(data.size(0)).to(device)
            print('got batch of size {0}, skipping'.format(data.shape))
            continue
        output = model(data, src_mask)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        save_interval = 2000
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data_post) // BPTT, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()
        if batch % save_interval == 0 and batch > 0:
            # v2 because we fear overfitting
            with open('saved_models/heb_char_model_style_v2.pkl', 'wb') as f:
                torch.save(model, f)
            print('saved model')

def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    src_mask = model.generate_square_subsequent_mask(BPTT).to(device)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, BPTT):
            data, targets = get_batch(data_source, i)
            if data.size(0) != BPTT:
                # src_mask = model.generate_square_subsequent_mask(data.size(0)).to(device)
                print('skipping sample eval because of shape: {0}'.format(data.shape))
                continue
            output = eval_model(data, src_mask)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)    

def predict(X):
  """
  Recives unactivated output as 2D tensor 
  Predicts classes
  """
  activated = torch.softmax(X, dim=1)
  _, prediction = torch.max(activated, 1)
  return prediction
  
def generate(model, vocab, start_string, genre, timestamp, temperature, max_len):
    '''
    This function gets a trained model and vocab and generates a random string
    using the model, seeded with the start_string string.
    The temparature value is used to generate a more diverse output (high value),
    then a conservative one (low value).
    '''
        
    # remove the EOS, we don't need it for generation
    # TODO: ADD EOS TO DATA
    # sequence = sequence[:-1]
    
    model.eval()
    words = [w for w in tokenizer(start_string)]
    
    for i in range(max_len):
        sequence = vocab.lookup_indices(words)
        sequence_ten = torch.LongTensor(sequence)
        length = sequence_ten.shape[0]
        expanded = torch.stack((sequence_ten, torch.tensor([genre]*length),\
                            torch.tensor([timestamp]*length)), 1)
        src_mask = model.generate_square_subsequent_mask(len(sequence)).to(device)
        forward = model(expanded.unsqueeze(1).to(device), src_mask)
        prediction = predict(forward[-1])
        next_word = vocab.itos[prediction]
        if next_word == EOS:
            i = max_len + 1
        else:
            words.append(next_word)
    return words

# %%
data = pd.read_pickle(PICKLE_PATH)
label_dict = {key: value for value, key in enumerate(data.label.unique())}

train_len = int(len(data) * 0.9)
train_data = data[0:train_len]
val_data = data[train_len:]

tokenizer = char_tokenizer
vocab = build_vocab_from_iterator(map(tokenizer,
                                      train_data['data'].__iter__()))

# Conform vocab to Bert standarts
# vocab.itos[0] = '[UNK]'
# vocab.itos[1] = '[PAD]'
# vocab.stoi['[UNK]'] = 0
# vocab.stoi['[PAD]'] = 1
# vocab.stoi.pop('<pad>')
# vocab.stoi.pop('<unk>')
# vocab.UNK = '[UNK]'

train_text_data = train_data['data']
train_label_data = train_data['label_num']
train_time_data = train_data['date'] - 2e5

val_text_data = val_data['data']
val_label_data = val_data['label_num']
val_time_data = val_data['date'] - 2e5

train_data_pre = data_process(train_text_data,\
                              train_label_data, train_time_data)
val_data_pre = data_process(val_text_data,\
                            val_label_data, val_time_data)

train_data_post = batchify(train_data_pre, BATCH_SIZE)
val_data_post = batchify(val_data_pre, EVAL_BATCH_SIZE)
# Out:
# 237033lines [00:21, 11119.38lines/s]

# %%
# sanity check
[vocab.itos[int(c)] for c in train_data_post[0:10][:,0][:,0]]
# Out:
# ['[SOS]', 'צ', 'ה', '"', 'ל', ' ', 'א', 'י', 'ת', 'ר']

# %%
ntokens = len(vocab.stoi) # the size of vocabulary
emsize = 768 # embedding dimension - 768 like in BERT
nhid = 3072 # the dimension of the feedforward network model in nn.TransformerEncoder - 3072 like in BERT
nlayers = 12 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder - we put 12 like in BERT
nhead = 12 # the number of heads in the multiheadattention models - we put 12 like in BERT
dropout = 0.1 # the dropout value - 0.1 like in BERT
# model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)
model = torch.load('saved_models/heb_char_model_style_v2.pkl')

# %%
criterion = nn.CrossEntropyLoss()
# lr = 5e-5 # learning rate
lr = 3e-5 # learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

# %%
torch.cuda.empty_cache()
import gc
# del variables
gc.collect()
# Out:
# 257

# %%
# %%time
best_val_loss = float("inf")
epochs = 40 # The number of epochs
best_model = None

model.cuda()

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(model, val_data_post)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model
        with open('heb_char_model.pkl', 'wb') as f:
            torch.save(model, f)

    scheduler.step()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:370: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# | epoch   1 |   200/19752 batches | lr 0.00 | ms/batch 374.48 | loss  0.87 | ppl     2.39
# | epoch   1 |   400/19752 batches | lr 0.00 | ms/batch 373.36 | loss  0.87 | ppl     2.38
# | epoch   1 |   600/19752 batches | lr 0.00 | ms/batch 373.43 | loss  0.88 | ppl     2.41
# | epoch   1 |   800/19752 batches | lr 0.00 | ms/batch 373.31 | loss  0.86 | ppl     2.37
# | epoch   1 |  1000/19752 batches | lr 0.00 | ms/batch 373.95 | loss  0.86 | ppl     2.37
# | epoch   1 |  1200/19752 batches | lr 0.00 | ms/batch 373.29 | loss  0.86 | ppl     2.37
# | epoch   1 |  1400/19752 batches | lr 0.00 | ms/batch 373.91 | loss  0.87 | ppl     2.38
# | epoch   1 |  1600/19752 batches | lr 0.00 | ms/batch 373.53 | loss  0.87 | ppl     2.38
# | epoch   1 |  1800/19752 batches | lr 0.00 | ms/batch 374.20 | loss  0.87 | ppl     2.39
# | epoch   1 |  2000/19752 batches | lr 0.00 | ms/batch 373.44 | loss  0.87 | ppl     2.39
# saved model
# | epoch   1 |  2200/19752 batches | lr 0.00 | ms/batch 381.34 | loss  0.86 | ppl     2.37
# | epoch   1 |  2400/19752 batches | lr 0.00 | ms/batch 373.44 | loss  0.87 | ppl     2.39
# | epoch   1 |  2600/19752 batches | lr 0.00 | ms/batch 373.75 | loss  0.87 | ppl     2.39
# | epoch   1 |  2800/19752 batches | lr 0.00 | ms/batch 374.09 | loss  0.87 | ppl     2.39
# | epoch   1 |  3000/19752 batches | lr 0.00 | ms/batch 374.12 | loss  0.86 | ppl     2.37
# | epoch   1 |  3200/19752 batches | lr 0.00 | ms/batch 373.78 | loss  0.86 | ppl     2.37
# | epoch   1 |  3400/19752 batches | lr 0.00 | ms/batch 373.93 | loss  0.87 | ppl     2.38
# | epoch   1 |  3600/19752 batches | lr 0.00 | ms/batch 374.05 | loss  0.87 | ppl     2.40
# | epoch   1 |  3800/19752 batches | lr 0.00 | ms/batch 374.17 | loss  0.86 | ppl     2.37
# | epoch   1 |  4000/19752 batches | lr 0.00 | ms/batch 374.02 | loss  0.87 | ppl     2.38
# saved model
# | epoch   1 |  4200/19752 batches | lr 0.00 | ms/batch 381.35 | loss  0.87 | ppl     2.39
# | epoch   1 |  4400/19752 batches | lr 0.00 | ms/batch 373.77 | loss  0.87 | ppl     2.38
# | epoch   1 |  4600/19752 batches | lr 0.00 | ms/batch 374.22 | loss  0.87 | ppl     2.39
# | epoch   1 |  4800/19752 batches | lr 0.00 | ms/batch 373.80 | loss  0.87 | ppl     2.38
# | epoch   1 |  5000/19752 batches | lr 0.00 | ms/batch 373.99 | loss  0.88 | ppl     2.40
# | epoch   1 |  5200/19752 batches | lr 0.00 | ms/batch 374.10 | loss  0.87 | ppl     2.38
# | epoch   1 |  5400/19752 batches | lr 0.00 | ms/batch 374.09 | loss  0.87 | ppl     2.38
# | epoch   1 |  5600/19752 batches | lr 0.00 | ms/batch 373.98 | loss  0.87 | ppl     2.39
# | epoch   1 |  5800/19752 batches | lr 0.00 | ms/batch 374.02 | loss  0.88 | ppl     2.40
# | epoch   1 |  6000/19752 batches | lr 0.00 | ms/batch 374.10 | loss  0.86 | ppl     2.37
# saved model
# | epoch   1 |  6200/19752 batches | lr 0.00 | ms/batch 382.25 | loss  0.86 | ppl     2.37
# | epoch   1 |  6400/19752 batches | lr 0.00 | ms/batch 374.04 | loss  0.87 | ppl     2.39
# | epoch   1 |  6600/19752 batches | lr 0.00 | ms/batch 373.99 | loss  0.87 | ppl     2.39
# | epoch   1 |  6800/19752 batches | lr 0.00 | ms/batch 374.04 | loss  0.87 | ppl     2.39
# | epoch   1 |  7000/19752 batches | lr 0.00 | ms/batch 374.59 | loss  0.86 | ppl     2.37
# | epoch   1 |  7200/19752 batches | lr 0.00 | ms/batch 374.42 | loss  0.87 | ppl     2.38
# | epoch   1 |  7400/19752 batches | lr 0.00 | ms/batch 374.05 | loss  0.87 | ppl     2.38
# | epoch   1 |  7600/19752 batches | lr 0.00 | ms/batch 374.11 | loss  0.87 | ppl     2.38
# | epoch   1 |  7800/19752 batches | lr 0.00 | ms/batch 374.40 | loss  0.86 | ppl     2.37
# | epoch   1 |  8000/19752 batches | lr 0.00 | ms/batch 374.36 | loss  0.87 | ppl     2.38
# saved model
# | epoch   1 |  8200/19752 batches | lr 0.00 | ms/batch 381.78 | loss  0.86 | ppl     2.37
# | epoch   1 |  8400/19752 batches | lr 0.00 | ms/batch 374.32 | loss  0.87 | ppl     2.39
# | epoch   1 |  8600/19752 batches | lr 0.00 | ms/batch 374.41 | loss  0.87 | ppl     2.38
# | epoch   1 |  8800/19752 batches | lr 0.00 | ms/batch 373.89 | loss  0.87 | ppl     2.39
# | epoch   1 |  9000/19752 batches | lr 0.00 | ms/batch 374.15 | loss  0.86 | ppl     2.37
# | epoch   1 |  9200/19752 batches | lr 0.00 | ms/batch 374.25 | loss  0.87 | ppl     2.39
# | epoch   1 |  9400/19752 batches | lr 0.00 | ms/batch 373.69 | loss  0.87 | ppl     2.39
# | epoch   1 |  9600/19752 batches | lr 0.00 | ms/batch 374.13 | loss  0.87 | ppl     2.38
# | epoch   1 |  9800/19752 batches | lr 0.00 | ms/batch 374.71 | loss  0.87 | ppl     2.39
# | epoch   1 | 10000/19752 batches | lr 0.00 | ms/batch 373.96 | loss  0.87 | ppl     2.39
# saved model
# | epoch   1 | 10200/19752 batches | lr 0.00 | ms/batch 382.23 | loss  0.88 | ppl     2.40
# | epoch   1 | 10400/19752 batches | lr 0.00 | ms/batch 373.90 | loss  0.87 | ppl     2.40
# | epoch   1 | 10600/19752 batches | lr 0.00 | ms/batch 374.51 | loss  0.88 | ppl     2.42
# | epoch   1 | 10800/19752 batches | lr 0.00 | ms/batch 374.36 | loss  0.87 | ppl     2.40
# | epoch   1 | 11000/19752 batches | lr 0.00 | ms/batch 374.63 | loss  0.87 | ppl     2.40
# | epoch   1 | 11200/19752 batches | lr 0.00 | ms/batch 374.16 | loss  0.88 | ppl     2.41
# | epoch   1 | 11400/19752 batches | lr 0.00 | ms/batch 373.59 | loss  0.88 | ppl     2.41
# | epoch   1 | 11600/19752 batches | lr 0.00 | ms/batch 374.08 | loss  0.88 | ppl     2.40
# | epoch   1 | 11800/19752 batches | lr 0.00 | ms/batch 373.83 | loss  0.87 | ppl     2.39
# | epoch   1 | 12000/19752 batches | lr 0.00 | ms/batch 373.79 | loss  0.87 | ppl     2.39
# saved model
# | epoch   1 | 12200/19752 batches | lr 0.00 | ms/batch 381.79 | loss  0.87 | ppl     2.40
# | epoch   1 | 12400/19752 batches | lr 0.00 | ms/batch 373.43 | loss  0.87 | ppl     2.39
# | epoch   1 | 12600/19752 batches | lr 0.00 | ms/batch 374.21 | loss  0.88 | ppl     2.41
# | epoch   1 | 12800/19752 batches | lr 0.00 | ms/batch 374.32 | loss  0.88 | ppl     2.40
# | epoch   1 | 13000/19752 batches | lr 0.00 | ms/batch 374.39 | loss  0.88 | ppl     2.42
# | epoch   1 | 13200/19752 batches | lr 0.00 | ms/batch 374.20 | loss  0.88 | ppl     2.41
# | epoch   1 | 13400/19752 batches | lr 0.00 | ms/batch 374.80 | loss  0.88 | ppl     2.40
# | epoch   1 | 13600/19752 batches | lr 0.00 | ms/batch 374.60 | loss  0.88 | ppl     2.40
# | epoch   1 | 13800/19752 batches | lr 0.00 | ms/batch 374.59 | loss  0.88 | ppl     2.41
# | epoch   1 | 14000/19752 batches | lr 0.00 | ms/batch 374.42 | loss  0.88 | ppl     2.42
# saved model
# | epoch   1 | 14200/19752 batches | lr 0.00 | ms/batch 382.98 | loss  0.88 | ppl     2.41
# | epoch   1 | 14400/19752 batches | lr 0.00 | ms/batch 374.65 | loss  0.88 | ppl     2.41
# | epoch   1 | 14600/19752 batches | lr 0.00 | ms/batch 374.13 | loss  0.88 | ppl     2.41
# | epoch   1 | 14800/19752 batches | lr 0.00 | ms/batch 375.78 | loss  0.88 | ppl     2.41
# | epoch   1 | 15000/19752 batches | lr 0.00 | ms/batch 374.79 | loss  0.87 | ppl     2.40
# | epoch   1 | 15200/19752 batches | lr 0.00 | ms/batch 375.01 | loss  0.88 | ppl     2.40
# | epoch   1 | 15400/19752 batches | lr 0.00 | ms/batch 374.22 | loss  0.88 | ppl     2.41
# | epoch   1 | 15600/19752 batches | lr 0.00 | ms/batch 375.63 | loss  0.88 | ppl     2.41
# | epoch   1 | 15800/19752 batches | lr 0.00 | ms/batch 374.29 | loss  0.87 | ppl     2.40
# | epoch   1 | 16000/19752 batches | lr 0.00 | ms/batch 373.56 | loss  0.87 | ppl     2.40
# saved model
# | epoch   1 | 16200/19752 batches | lr 0.00 | ms/batch 381.61 | loss  0.88 | ppl     2.42
# | epoch   1 | 16400/19752 batches | lr 0.00 | ms/batch 373.83 | loss  0.88 | ppl     2.41
# | epoch   1 | 16600/19752 batches | lr 0.00 | ms/batch 375.06 | loss  0.89 | ppl     2.42
# | epoch   1 | 16800/19752 batches | lr 0.00 | ms/batch 375.50 | loss  0.88 | ppl     2.42
# | epoch   1 | 17000/19752 batches | lr 0.00 | ms/batch 375.51 | loss  0.88 | ppl     2.42
# | epoch   1 | 17200/19752 batches | lr 0.00 | ms/batch 375.59 | loss  0.88 | ppl     2.42
# | epoch   1 | 17400/19752 batches | lr 0.00 | ms/batch 375.14 | loss  0.89 | ppl     2.42
# | epoch   1 | 17600/19752 batches | lr 0.00 | ms/batch 375.94 | loss  0.89 | ppl     2.43
# | epoch   1 | 17800/19752 batches | lr 0.00 | ms/batch 374.90 | loss  0.89 | ppl     2.43
# | epoch   1 | 18000/19752 batches | lr 0.00 | ms/batch 374.80 | loss  0.89 | ppl     2.43
# saved model
# | epoch   1 | 18200/19752 batches | lr 0.00 | ms/batch 382.32 | loss  0.88 | ppl     2.42
# | epoch   1 | 18400/19752 batches | lr 0.00 | ms/batch 373.91 | loss  0.88 | ppl     2.41
# | epoch   1 | 18600/19752 batches | lr 0.00 | ms/batch 374.28 | loss  0.89 | ppl     2.43
# | epoch   1 | 18800/19752 batches | lr 0.00 | ms/batch 373.76 | loss  0.89 | ppl     2.43
# | epoch   1 | 19000/19752 batches | lr 0.00 | ms/batch 375.20 | loss  0.89 | ppl     2.44
# | epoch   1 | 19200/19752 batches | lr 0.00 | ms/batch 374.79 | loss  0.89 | ppl     2.44
# | epoch   1 | 19400/19752 batches | lr 0.00 | ms/batch 374.78 | loss  0.89 | ppl     2.44
# | epoch   1 | 19600/19752 batches | lr 0.00 | ms/batch 374.54 | loss  0.89 | ppl     2.44
# got batch of size torch.Size([383, 12, 3]), skipping
# skipping sample eval because of shape: torch.Size([340, 6, 3])
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 7670.90s | valid loss  0.93 | valid ppl     2.55
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/19752 batches | lr 0.00 | ms/batch 376.37 | loss  0.87 | ppl     2.38
# | epoch   2 |   400/19752 batches | lr 0.00 | ms/batch 374.22 | loss  0.87 | ppl     2.38
# | epoch   2 |   600/19752 batches | lr 0.00 | ms/batch 374.79 | loss  0.88 | ppl     2.40
# | epoch   2 |   800/19752 batches | lr 0.00 | ms/batch 373.89 | loss  0.86 | ppl     2.36
# | epoch   2 |  1000/19752 batches | lr 0.00 | ms/batch 374.96 | loss  0.86 | ppl     2.36
# | epoch   2 |  1200/19752 batches | lr 0.00 | ms/batch 374.62 | loss  0.86 | ppl     2.37
# | epoch   2 |  1400/19752 batches | lr 0.00 | ms/batch 374.34 | loss  0.87 | ppl     2.38
# | epoch   2 |  1600/19752 batches | lr 0.00 | ms/batch 374.12 | loss  0.87 | ppl     2.38
# | epoch   2 |  1800/19752 batches | lr 0.00 | ms/batch 374.10 | loss  0.87 | ppl     2.38
# | epoch   2 |  2000/19752 batches | lr 0.00 | ms/batch 374.91 | loss  0.87 | ppl     2.39
# saved model
# | epoch   2 |  2200/19752 batches | lr 0.00 | ms/batch 382.24 | loss  0.86 | ppl     2.36
# | epoch   2 |  2400/19752 batches | lr 0.00 | ms/batch 373.80 | loss  0.87 | ppl     2.39
# | epoch   2 |  2600/19752 batches | lr 0.00 | ms/batch 374.40 | loss  0.87 | ppl     2.38
# | epoch   2 |  2800/19752 batches | lr 0.00 | ms/batch 374.41 | loss  0.87 | ppl     2.38
# | epoch   2 |  3000/19752 batches | lr 0.00 | ms/batch 375.00 | loss  0.86 | ppl     2.36
# | epoch   2 |  3200/19752 batches | lr 0.00 | ms/batch 374.70 | loss  0.86 | ppl     2.36
# | epoch   2 |  3400/19752 batches | lr 0.00 | ms/batch 375.39 | loss  0.86 | ppl     2.37
# | epoch   2 |  3600/19752 batches | lr 0.00 | ms/batch 374.38 | loss  0.87 | ppl     2.39
# | epoch   2 |  3800/19752 batches | lr 0.00 | ms/batch 374.36 | loss  0.86 | ppl     2.37
# | epoch   2 |  4000/19752 batches | lr 0.00 | ms/batch 374.05 | loss  0.86 | ppl     2.37
# saved model
# | epoch   2 |  4200/19752 batches | lr 0.00 | ms/batch 382.34 | loss  0.87 | ppl     2.39
# | epoch   2 |  4400/19752 batches | lr 0.00 | ms/batch 374.80 | loss  0.86 | ppl     2.37
# | epoch   2 |  4600/19752 batches | lr 0.00 | ms/batch 374.74 | loss  0.87 | ppl     2.38
# | epoch   2 |  4800/19752 batches | lr 0.00 | ms/batch 374.26 | loss  0.87 | ppl     2.38
# | epoch   2 |  5000/19752 batches | lr 0.00 | ms/batch 374.61 | loss  0.87 | ppl     2.40
# | epoch   2 |  5200/19752 batches | lr 0.00 | ms/batch 373.93 | loss  0.86 | ppl     2.37
# | epoch   2 |  5400/19752 batches | lr 0.00 | ms/batch 374.49 | loss  0.86 | ppl     2.37
# | epoch   2 |  5600/19752 batches | lr 0.00 | ms/batch 375.83 | loss  0.87 | ppl     2.38
# | epoch   2 |  5800/19752 batches | lr 0.00 | ms/batch 374.52 | loss  0.87 | ppl     2.40
# | epoch   2 |  6000/19752 batches | lr 0.00 | ms/batch 374.45 | loss  0.86 | ppl     2.36
# saved model
# | epoch   2 |  6200/19752 batches | lr 0.00 | ms/batch 382.22 | loss  0.86 | ppl     2.36
# | epoch   2 |  6400/19752 batches | lr 0.00 | ms/batch 374.59 | loss  0.87 | ppl     2.38
# | epoch   2 |  6600/19752 batches | lr 0.00 | ms/batch 374.05 | loss  0.87 | ppl     2.38
# | epoch   2 |  6800/19752 batches | lr 0.00 | ms/batch 373.51 | loss  0.87 | ppl     2.38
# | epoch   2 |  7000/19752 batches | lr 0.00 | ms/batch 374.21 | loss  0.86 | ppl     2.36
# | epoch   2 |  7200/19752 batches | lr 0.00 | ms/batch 374.92 | loss  0.86 | ppl     2.37
# | epoch   2 |  7400/19752 batches | lr 0.00 | ms/batch 375.00 | loss  0.86 | ppl     2.37
# | epoch   2 |  7600/19752 batches | lr 0.00 | ms/batch 374.00 | loss  0.86 | ppl     2.37
# | epoch   2 |  7800/19752 batches | lr 0.00 | ms/batch 373.87 | loss  0.86 | ppl     2.36
# | epoch   2 |  8000/19752 batches | lr 0.00 | ms/batch 374.97 | loss  0.87 | ppl     2.38
# saved model
# | epoch   2 |  8200/19752 batches | lr 0.00 | ms/batch 382.19 | loss  0.86 | ppl     2.36
# | epoch   2 |  8400/19752 batches | lr 0.00 | ms/batch 374.88 | loss  0.87 | ppl     2.38
# | epoch   2 |  8600/19752 batches | lr 0.00 | ms/batch 375.54 | loss  0.87 | ppl     2.38
# | epoch   2 |  8800/19752 batches | lr 0.00 | ms/batch 374.64 | loss  0.87 | ppl     2.38
# | epoch   2 |  9000/19752 batches | lr 0.00 | ms/batch 374.57 | loss  0.86 | ppl     2.36
# | epoch   2 |  9200/19752 batches | lr 0.00 | ms/batch 375.03 | loss  0.87 | ppl     2.39
# | epoch   2 |  9400/19752 batches | lr 0.00 | ms/batch 374.51 | loss  0.87 | ppl     2.38
# | epoch   2 |  9600/19752 batches | lr 0.00 | ms/batch 375.27 | loss  0.86 | ppl     2.37
# | epoch   2 |  9800/19752 batches | lr 0.00 | ms/batch 375.40 | loss  0.87 | ppl     2.38
# | epoch   2 | 10000/19752 batches | lr 0.00 | ms/batch 375.21 | loss  0.87 | ppl     2.38
# saved model
# | epoch   2 | 10200/19752 batches | lr 0.00 | ms/batch 382.55 | loss  0.87 | ppl     2.39
# | epoch   2 | 10400/19752 batches | lr 0.00 | ms/batch 375.22 | loss  0.87 | ppl     2.39
# | epoch   2 | 10600/19752 batches | lr 0.00 | ms/batch 374.83 | loss  0.88 | ppl     2.40
# | epoch   2 | 10800/19752 batches | lr 0.00 | ms/batch 375.37 | loss  0.87 | ppl     2.39
# | epoch   2 | 11000/19752 batches | lr 0.00 | ms/batch 376.52 | loss  0.87 | ppl     2.39
# | epoch   2 | 11200/19752 batches | lr 0.00 | ms/batch 375.14 | loss  0.87 | ppl     2.40
# | epoch   2 | 11400/19752 batches | lr 0.00 | ms/batch 374.28 | loss  0.87 | ppl     2.40
# | epoch   2 | 11600/19752 batches | lr 0.00 | ms/batch 374.66 | loss  0.87 | ppl     2.39
# | epoch   2 | 11800/19752 batches | lr 0.00 | ms/batch 375.36 | loss  0.87 | ppl     2.38
# | epoch   2 | 12000/19752 batches | lr 0.00 | ms/batch 375.03 | loss  0.87 | ppl     2.38
# saved model
# | epoch   2 | 12200/19752 batches | lr 0.00 | ms/batch 382.81 | loss  0.87 | ppl     2.39
# | epoch   2 | 12400/19752 batches | lr 0.00 | ms/batch 374.07 | loss  0.87 | ppl     2.38
# | epoch   2 | 12600/19752 batches | lr 0.00 | ms/batch 374.55 | loss  0.88 | ppl     2.40
# | epoch   2 | 12800/19752 batches | lr 0.00 | ms/batch 374.53 | loss  0.87 | ppl     2.39
# | epoch   2 | 13000/19752 batches | lr 0.00 | ms/batch 375.69 | loss  0.88 | ppl     2.40
# | epoch   2 | 13200/19752 batches | lr 0.00 | ms/batch 375.47 | loss  0.88 | ppl     2.40
# | epoch   2 | 13400/19752 batches | lr 0.00 | ms/batch 375.45 | loss  0.87 | ppl     2.39
# | epoch   2 | 13600/19752 batches | lr 0.00 | ms/batch 375.13 | loss  0.87 | ppl     2.39
# | epoch   2 | 13800/19752 batches | lr 0.00 | ms/batch 375.73 | loss  0.88 | ppl     2.40
# | epoch   2 | 14000/19752 batches | lr 0.00 | ms/batch 375.50 | loss  0.88 | ppl     2.40
# saved model
# | epoch   2 | 14200/19752 batches | lr 0.00 | ms/batch 382.84 | loss  0.87 | ppl     2.40
# | epoch   2 | 14400/19752 batches | lr 0.00 | ms/batch 374.53 | loss  0.87 | ppl     2.40
# | epoch   2 | 14600/19752 batches | lr 0.00 | ms/batch 375.70 | loss  0.87 | ppl     2.40
# | epoch   2 | 14800/19752 batches | lr 0.00 | ms/batch 374.13 | loss  0.88 | ppl     2.40
# | epoch   2 | 15000/19752 batches | lr 0.00 | ms/batch 374.55 | loss  0.87 | ppl     2.39
# | epoch   2 | 15200/19752 batches | lr 0.00 | ms/batch 374.60 | loss  0.87 | ppl     2.39
# | epoch   2 | 15400/19752 batches | lr 0.00 | ms/batch 375.72 | loss  0.87 | ppl     2.40
# | epoch   2 | 15600/19752 batches | lr 0.00 | ms/batch 376.08 | loss  0.88 | ppl     2.40
# | epoch   2 | 15800/19752 batches | lr 0.00 | ms/batch 375.29 | loss  0.87 | ppl     2.38
# | epoch   2 | 16000/19752 batches | lr 0.00 | ms/batch 376.18 | loss  0.87 | ppl     2.39
# saved model
# | epoch   2 | 16200/19752 batches | lr 0.00 | ms/batch 383.45 | loss  0.88 | ppl     2.40
# | epoch   2 | 16400/19752 batches | lr 0.00 | ms/batch 375.12 | loss  0.87 | ppl     2.39
# | epoch   2 | 16600/19752 batches | lr 0.00 | ms/batch 374.52 | loss  0.88 | ppl     2.41
# | epoch   2 | 16800/19752 batches | lr 0.00 | ms/batch 375.02 | loss  0.88 | ppl     2.40
# | epoch   2 | 17000/19752 batches | lr 0.00 | ms/batch 374.65 | loss  0.88 | ppl     2.40
# | epoch   2 | 17200/19752 batches | lr 0.00 | ms/batch 374.75 | loss  0.87 | ppl     2.40
# | epoch   2 | 17400/19752 batches | lr 0.00 | ms/batch 374.87 | loss  0.88 | ppl     2.41
# | epoch   2 | 17600/19752 batches | lr 0.00 | ms/batch 375.63 | loss  0.88 | ppl     2.41
# | epoch   2 | 17800/19752 batches | lr 0.00 | ms/batch 375.19 | loss  0.88 | ppl     2.41
# | epoch   2 | 18000/19752 batches | lr 0.00 | ms/batch 376.23 | loss  0.88 | ppl     2.41
# saved model
# | epoch   2 | 18200/19752 batches | lr 0.00 | ms/batch 382.69 | loss  0.88 | ppl     2.40
# | epoch   2 | 18400/19752 batches | lr 0.00 | ms/batch 376.01 | loss  0.87 | ppl     2.39
# | epoch   2 | 18600/19752 batches | lr 0.00 | ms/batch 374.97 | loss  0.88 | ppl     2.41
# | epoch   2 | 18800/19752 batches | lr 0.00 | ms/batch 375.44 | loss  0.88 | ppl     2.42
# | epoch   2 | 19000/19752 batches | lr 0.00 | ms/batch 374.82 | loss  0.88 | ppl     2.42
# | epoch   2 | 19200/19752 batches | lr 0.00 | ms/batch 375.15 | loss  0.88 | ppl     2.42
# | epoch   2 | 19400/19752 batches | lr 0.00 | ms/batch 374.60 | loss  0.88 | ppl     2.42
# | epoch   2 | 19600/19752 batches | lr 0.00 | ms/batch 375.56 | loss  0.88 | ppl     2.42
# got batch of size torch.Size([383, 12, 3]), skipping
# skipping sample eval because of shape: torch.Size([340, 6, 3])
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 7683.37s | valid loss  0.93 | valid ppl     2.54
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/19752 batches | lr 0.00 | ms/batch 376.99 | loss  0.86 | ppl     2.37
# | epoch   3 |   400/19752 batches | lr 0.00 | ms/batch 374.96 | loss  0.86 | ppl     2.37
# | epoch   3 |   600/19752 batches | lr 0.00 | ms/batch 375.73 | loss  0.87 | ppl     2.39
# | epoch   3 |   800/19752 batches | lr 0.00 | ms/batch 375.91 | loss  0.86 | ppl     2.35
# | epoch   3 |  1000/19752 batches | lr 0.00 | ms/batch 377.05 | loss  0.85 | ppl     2.35
# | epoch   3 |  1200/19752 batches | lr 0.00 | ms/batch 375.25 | loss  0.86 | ppl     2.36
# | epoch   3 |  1400/19752 batches | lr 0.00 | ms/batch 375.30 | loss  0.86 | ppl     2.37
# | epoch   3 |  1600/19752 batches | lr 0.00 | ms/batch 375.52 | loss  0.86 | ppl     2.37
# | epoch   3 |  1800/19752 batches | lr 0.00 | ms/batch 376.55 | loss  0.86 | ppl     2.37
# | epoch   3 |  2000/19752 batches | lr 0.00 | ms/batch 376.03 | loss  0.87 | ppl     2.38
# saved model
# | epoch   3 |  2200/19752 batches | lr 0.00 | ms/batch 384.62 | loss  0.85 | ppl     2.35
# | epoch   3 |  2400/19752 batches | lr 0.00 | ms/batch 375.88 | loss  0.87 | ppl     2.38
# | epoch   3 |  2600/19752 batches | lr 0.00 | ms/batch 375.82 | loss  0.86 | ppl     2.37
# | epoch   3 |  2800/19752 batches | lr 0.00 | ms/batch 375.67 | loss  0.87 | ppl     2.38
# | epoch   3 |  3000/19752 batches | lr 0.00 | ms/batch 375.11 | loss  0.86 | ppl     2.36
# | epoch   3 |  3200/19752 batches | lr 0.00 | ms/batch 375.94 | loss  0.86 | ppl     2.36
# | epoch   3 |  3400/19752 batches | lr 0.00 | ms/batch 375.42 | loss  0.86 | ppl     2.36
# | epoch   3 |  3600/19752 batches | lr 0.00 | ms/batch 374.14 | loss  0.87 | ppl     2.38
# | epoch   3 |  3800/19752 batches | lr 0.00 | ms/batch 375.08 | loss  0.86 | ppl     2.36
# | epoch   3 |  4000/19752 batches | lr 0.00 | ms/batch 375.22 | loss  0.86 | ppl     2.36
# saved model
# | epoch   3 |  4200/19752 batches | lr 0.00 | ms/batch 382.59 | loss  0.87 | ppl     2.38
# | epoch   3 |  4400/19752 batches | lr 0.00 | ms/batch 375.10 | loss  0.86 | ppl     2.36
# | epoch   3 |  4600/19752 batches | lr 0.00 | ms/batch 375.53 | loss  0.86 | ppl     2.37
# | epoch   3 |  4800/19752 batches | lr 0.00 | ms/batch 374.73 | loss  0.86 | ppl     2.37
# | epoch   3 |  5000/19752 batches | lr 0.00 | ms/batch 374.67 | loss  0.87 | ppl     2.39
# | epoch   3 |  5200/19752 batches | lr 0.00 | ms/batch 374.84 | loss  0.86 | ppl     2.36
# | epoch   3 |  5400/19752 batches | lr 0.00 | ms/batch 376.31 | loss  0.86 | ppl     2.36
# | epoch   3 |  5600/19752 batches | lr 0.00 | ms/batch 375.91 | loss  0.86 | ppl     2.37
# | epoch   3 |  5800/19752 batches | lr 0.00 | ms/batch 375.59 | loss  0.87 | ppl     2.39
# | epoch   3 |  6000/19752 batches | lr 0.00 | ms/batch 375.31 | loss  0.86 | ppl     2.35
# saved model
# | epoch   3 |  6200/19752 batches | lr 0.00 | ms/batch 382.48 | loss  0.86 | ppl     2.35
# | epoch   3 |  6400/19752 batches | lr 0.00 | ms/batch 375.04 | loss  0.86 | ppl     2.37
# | epoch   3 |  6600/19752 batches | lr 0.00 | ms/batch 375.91 | loss  0.86 | ppl     2.37
# | epoch   3 |  6800/19752 batches | lr 0.00 | ms/batch 375.81 | loss  0.86 | ppl     2.37
# | epoch   3 |  7000/19752 batches | lr 0.00 | ms/batch 375.78 | loss  0.86 | ppl     2.35
# | epoch   3 |  7200/19752 batches | lr 0.00 | ms/batch 374.79 | loss  0.86 | ppl     2.36
# | epoch   3 |  7400/19752 batches | lr 0.00 | ms/batch 374.78 | loss  0.86 | ppl     2.36
# | epoch   3 |  7600/19752 batches | lr 0.00 | ms/batch 375.62 | loss  0.86 | ppl     2.36
# | epoch   3 |  7800/19752 batches | lr 0.00 | ms/batch 374.31 | loss  0.85 | ppl     2.35
# | epoch   3 |  8000/19752 batches | lr 0.00 | ms/batch 375.56 | loss  0.86 | ppl     2.37
# saved model
# | epoch   3 |  8200/19752 batches | lr 0.00 | ms/batch 383.75 | loss  0.86 | ppl     2.35
# | epoch   3 |  8400/19752 batches | lr 0.00 | ms/batch 375.95 | loss  0.86 | ppl     2.37
# | epoch   3 |  8600/19752 batches | lr 0.00 | ms/batch 374.99 | loss  0.86 | ppl     2.37
# | epoch   3 |  8800/19752 batches | lr 0.00 | ms/batch 375.59 | loss  0.86 | ppl     2.37
# | epoch   3 |  9000/19752 batches | lr 0.00 | ms/batch 374.44 | loss  0.85 | ppl     2.35
# | epoch   3 |  9200/19752 batches | lr 0.00 | ms/batch 374.52 | loss  0.87 | ppl     2.38
# | epoch   3 |  9400/19752 batches | lr 0.00 | ms/batch 374.82 | loss  0.86 | ppl     2.37
# | epoch   3 |  9600/19752 batches | lr 0.00 | ms/batch 374.30 | loss  0.86 | ppl     2.36
# | epoch   3 |  9800/19752 batches | lr 0.00 | ms/batch 375.39 | loss  0.86 | ppl     2.37
# | epoch   3 | 10000/19752 batches | lr 0.00 | ms/batch 376.53 | loss  0.86 | ppl     2.37
# saved model
# | epoch   3 | 10200/19752 batches | lr 0.00 | ms/batch 382.93 | loss  0.87 | ppl     2.38
# | epoch   3 | 10400/19752 batches | lr 0.00 | ms/batch 374.91 | loss  0.86 | ppl     2.37
# | epoch   3 | 10600/19752 batches | lr 0.00 | ms/batch 374.84 | loss  0.87 | ppl     2.39
# | epoch   3 | 10800/19752 batches | lr 0.00 | ms/batch 374.74 | loss  0.86 | ppl     2.37
# | epoch   3 | 11000/19752 batches | lr 0.00 | ms/batch 374.20 | loss  0.87 | ppl     2.38
# | epoch   3 | 11200/19752 batches | lr 0.00 | ms/batch 375.21 | loss  0.87 | ppl     2.39
# | epoch   3 | 11400/19752 batches | lr 0.00 | ms/batch 374.59 | loss  0.87 | ppl     2.38
# | epoch   3 | 11600/19752 batches | lr 0.00 | ms/batch 375.43 | loss  0.87 | ppl     2.38
# | epoch   3 | 11800/19752 batches | lr 0.00 | ms/batch 375.50 | loss  0.86 | ppl     2.37
# | epoch   3 | 12000/19752 batches | lr 0.00 | ms/batch 374.52 | loss  0.86 | ppl     2.37
# saved model
# | epoch   3 | 12200/19752 batches | lr 0.00 | ms/batch 382.52 | loss  0.86 | ppl     2.37
# | epoch   3 | 12400/19752 batches | lr 0.00 | ms/batch 374.92 | loss  0.86 | ppl     2.37
# | epoch   3 | 12600/19752 batches | lr 0.00 | ms/batch 374.73 | loss  0.87 | ppl     2.39
# | epoch   3 | 12800/19752 batches | lr 0.00 | ms/batch 374.24 | loss  0.87 | ppl     2.38
# | epoch   3 | 13000/19752 batches | lr 0.00 | ms/batch 375.01 | loss  0.87 | ppl     2.39
# | epoch   3 | 13200/19752 batches | lr 0.00 | ms/batch 375.94 | loss  0.87 | ppl     2.39
# | epoch   3 | 13400/19752 batches | lr 0.00 | ms/batch 374.94 | loss  0.87 | ppl     2.38
# | epoch   3 | 13600/19752 batches | lr 0.00 | ms/batch 376.40 | loss  0.87 | ppl     2.38
# | epoch   3 | 13800/19752 batches | lr 0.00 | ms/batch 375.71 | loss  0.87 | ppl     2.39
# | epoch   3 | 14000/19752 batches | lr 0.00 | ms/batch 376.42 | loss  0.87 | ppl     2.39
# saved model
# | epoch   3 | 14200/19752 batches | lr 0.00 | ms/batch 384.24 | loss  0.87 | ppl     2.38
# | epoch   3 | 14400/19752 batches | lr 0.00 | ms/batch 375.29 | loss  0.87 | ppl     2.38
# | epoch   3 | 14600/19752 batches | lr 0.00 | ms/batch 375.95 | loss  0.87 | ppl     2.39
# | epoch   3 | 14800/19752 batches | lr 0.00 | ms/batch 374.80 | loss  0.87 | ppl     2.39
# | epoch   3 | 15000/19752 batches | lr 0.00 | ms/batch 375.03 | loss  0.87 | ppl     2.38
# | epoch   3 | 15200/19752 batches | lr 0.00 | ms/batch 375.83 | loss  0.87 | ppl     2.38
# | epoch   3 | 15400/19752 batches | lr 0.00 | ms/batch 376.26 | loss  0.87 | ppl     2.39
# | epoch   3 | 15600/19752 batches | lr 0.00 | ms/batch 375.71 | loss  0.87 | ppl     2.39
# | epoch   3 | 15800/19752 batches | lr 0.00 | ms/batch 375.94 | loss  0.86 | ppl     2.37
# | epoch   3 | 16000/19752 batches | lr 0.00 | ms/batch 375.53 | loss  0.86 | ppl     2.37
# saved model
# | epoch   3 | 16200/19752 batches | lr 0.00 | ms/batch 382.97 | loss  0.87 | ppl     2.38
# | epoch   3 | 16400/19752 batches | lr 0.00 | ms/batch 374.63 | loss  0.86 | ppl     2.37
# | epoch   3 | 16600/19752 batches | lr 0.00 | ms/batch 373.90 | loss  0.87 | ppl     2.39
# | epoch   3 | 16800/19752 batches | lr 0.00 | ms/batch 374.39 | loss  0.87 | ppl     2.39
# | epoch   3 | 17000/19752 batches | lr 0.00 | ms/batch 374.33 | loss  0.87 | ppl     2.39
# | epoch   3 | 17200/19752 batches | lr 0.00 | ms/batch 374.25 | loss  0.87 | ppl     2.38
# | epoch   3 | 17400/19752 batches | lr 0.00 | ms/batch 374.81 | loss  0.87 | ppl     2.39
# | epoch   3 | 17600/19752 batches | lr 0.00 | ms/batch 373.70 | loss  0.87 | ppl     2.40
# | epoch   3 | 17800/19752 batches | lr 0.00 | ms/batch 375.54 | loss  0.87 | ppl     2.40
# | epoch   3 | 18000/19752 batches | lr 0.00 | ms/batch 375.29 | loss  0.87 | ppl     2.40
# saved model
# | epoch   3 | 18200/19752 batches | lr 0.00 | ms/batch 381.98 | loss  0.87 | ppl     2.39
# | epoch   3 | 18400/19752 batches | lr 0.00 | ms/batch 375.69 | loss  0.87 | ppl     2.38
# | epoch   3 | 18600/19752 batches | lr 0.00 | ms/batch 376.42 | loss  0.88 | ppl     2.40
# | epoch   3 | 18800/19752 batches | lr 0.00 | ms/batch 375.98 | loss  0.88 | ppl     2.40
# | epoch   3 | 19000/19752 batches | lr 0.00 | ms/batch 376.30 | loss  0.88 | ppl     2.41
# | epoch   3 | 19200/19752 batches | lr 0.00 | ms/batch 376.37 | loss  0.88 | ppl     2.40
# | epoch   3 | 19400/19752 batches | lr 0.00 | ms/batch 374.62 | loss  0.88 | ppl     2.41
# | epoch   3 | 19600/19752 batches | lr 0.00 | ms/batch 375.61 | loss  0.88 | ppl     2.40
# got batch of size torch.Size([383, 12, 3]), skipping
# skipping sample eval because of shape: torch.Size([340, 6, 3])
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 7692.52s | valid loss  0.93 | valid ppl     2.54
# -----------------------------------------------------------------------------------------
# | epoch   4 |   200/19752 batches | lr 0.00 | ms/batch 376.88 | loss  0.86 | ppl     2.36
# | epoch   4 |   400/19752 batches | lr 0.00 | ms/batch 375.00 | loss  0.86 | ppl     2.36
# | epoch   4 |   600/19752 batches | lr 0.00 | ms/batch 374.50 | loss  0.87 | ppl     2.38
# | epoch   4 |   800/19752 batches | lr 0.00 | ms/batch 375.82 | loss  0.85 | ppl     2.35
# | epoch   4 |  1000/19752 batches | lr 0.00 | ms/batch 374.64 | loss  0.85 | ppl     2.34
# | epoch   4 |  1200/19752 batches | lr 0.00 | ms/batch 375.70 | loss  0.85 | ppl     2.35
# | epoch   4 |  1400/19752 batches | lr 0.00 | ms/batch 375.73 | loss  0.86 | ppl     2.36
# | epoch   4 |  1600/19752 batches | lr 0.00 | ms/batch 376.68 | loss  0.86 | ppl     2.36
# | epoch   4 |  1800/19752 batches | lr 0.00 | ms/batch 375.15 | loss  0.86 | ppl     2.36
# | epoch   4 |  2000/19752 batches | lr 0.00 | ms/batch 375.33 | loss  0.86 | ppl     2.37
# saved model
# | epoch   4 |  2200/19752 batches | lr 0.00 | ms/batch 383.77 | loss  0.85 | ppl     2.34
# | epoch   4 |  2400/19752 batches | lr 0.00 | ms/batch 376.19 | loss  0.86 | ppl     2.37
# | epoch   4 |  2600/19752 batches | lr 0.00 | ms/batch 375.61 | loss  0.86 | ppl     2.36
# | epoch   4 |  2800/19752 batches | lr 0.00 | ms/batch 374.73 | loss  0.86 | ppl     2.37
# | epoch   4 |  3000/19752 batches | lr 0.00 | ms/batch 375.53 | loss  0.85 | ppl     2.35
# | epoch   4 |  3200/19752 batches | lr 0.00 | ms/batch 374.72 | loss  0.85 | ppl     2.35
# | epoch   4 |  3400/19752 batches | lr 0.00 | ms/batch 374.88 | loss  0.86 | ppl     2.36
# | epoch   4 |  3600/19752 batches | lr 0.00 | ms/batch 376.77 | loss  0.86 | ppl     2.37
# | epoch   4 |  3800/19752 batches | lr 0.00 | ms/batch 376.02 | loss  0.85 | ppl     2.35
# | epoch   4 |  4000/19752 batches | lr 0.00 | ms/batch 375.34 | loss  0.86 | ppl     2.35
# saved model
# | epoch   4 |  4200/19752 batches | lr 0.00 | ms/batch 382.89 | loss  0.86 | ppl     2.37
# | epoch   4 |  4400/19752 batches | lr 0.00 | ms/batch 375.47 | loss  0.86 | ppl     2.35
# | epoch   4 |  4600/19752 batches | lr 0.00 | ms/batch 374.85 | loss  0.86 | ppl     2.36
# | epoch   4 |  4800/19752 batches | lr 0.00 | ms/batch 376.00 | loss  0.86 | ppl     2.36
# | epoch   4 |  5000/19752 batches | lr 0.00 | ms/batch 375.96 | loss  0.87 | ppl     2.38
# | epoch   4 |  5200/19752 batches | lr 0.00 | ms/batch 375.56 | loss  0.85 | ppl     2.35
# | epoch   4 |  5400/19752 batches | lr 0.00 | ms/batch 374.74 | loss  0.86 | ppl     2.36
# | epoch   4 |  5600/19752 batches | lr 0.00 | ms/batch 374.70 | loss  0.86 | ppl     2.36
# | epoch   4 |  5800/19752 batches | lr 0.00 | ms/batch 374.70 | loss  0.87 | ppl     2.38
# | epoch   4 |  6000/19752 batches | lr 0.00 | ms/batch 374.77 | loss  0.85 | ppl     2.35
# saved model
# | epoch   4 |  6200/19752 batches | lr 0.00 | ms/batch 382.97 | loss  0.85 | ppl     2.34
# | epoch   4 |  6400/19752 batches | lr 0.00 | ms/batch 374.90 | loss  0.86 | ppl     2.36
# | epoch   4 |  6600/19752 batches | lr 0.00 | ms/batch 375.51 | loss  0.86 | ppl     2.36
# | epoch   4 |  6800/19752 batches | lr 0.00 | ms/batch 375.05 | loss  0.86 | ppl     2.36
# | epoch   4 |  7000/19752 batches | lr 0.00 | ms/batch 374.87 | loss  0.85 | ppl     2.34
# | epoch   4 |  7200/19752 batches | lr 0.00 | ms/batch 375.21 | loss  0.85 | ppl     2.35
# | epoch   4 |  7400/19752 batches | lr 0.00 | ms/batch 374.97 | loss  0.86 | ppl     2.35
# | epoch   4 |  7600/19752 batches | lr 0.00 | ms/batch 375.02 | loss  0.85 | ppl     2.35
# | epoch   4 |  7800/19752 batches | lr 0.00 | ms/batch 376.75 | loss  0.85 | ppl     2.34
# | epoch   4 |  8000/19752 batches | lr 0.00 | ms/batch 375.51 | loss  0.86 | ppl     2.36
# saved model
# | epoch   4 |  8200/19752 batches | lr 0.00 | ms/batch 383.81 | loss  0.85 | ppl     2.35
# | epoch   4 |  8400/19752 batches | lr 0.00 | ms/batch 375.27 | loss  0.86 | ppl     2.36
# | epoch   4 |  8600/19752 batches | lr 0.00 | ms/batch 374.73 | loss  0.86 | ppl     2.36
# | epoch   4 |  8800/19752 batches | lr 0.00 | ms/batch 375.52 | loss  0.86 | ppl     2.36
# | epoch   4 |  9000/19752 batches | lr 0.00 | ms/batch 375.32 | loss  0.85 | ppl     2.34
# | epoch   4 |  9200/19752 batches | lr 0.00 | ms/batch 375.85 | loss  0.86 | ppl     2.37
# | epoch   4 |  9400/19752 batches | lr 0.00 | ms/batch 375.90 | loss  0.86 | ppl     2.36
# | epoch   4 |  9600/19752 batches | lr 0.00 | ms/batch 374.97 | loss  0.85 | ppl     2.35
# | epoch   4 |  9800/19752 batches | lr 0.00 | ms/batch 374.77 | loss  0.86 | ppl     2.36
# | epoch   4 | 10000/19752 batches | lr 0.00 | ms/batch 374.90 | loss  0.86 | ppl     2.36
# saved model
# | epoch   4 | 10200/19752 batches | lr 0.00 | ms/batch 382.60 | loss  0.86 | ppl     2.37
# | epoch   4 | 10400/19752 batches | lr 0.00 | ms/batch 374.96 | loss  0.86 | ppl     2.36
# | epoch   4 | 10600/19752 batches | lr 0.00 | ms/batch 375.47 | loss  0.87 | ppl     2.38
# | epoch   4 | 10800/19752 batches | lr 0.00 | ms/batch 375.06 | loss  0.86 | ppl     2.36
# | epoch   4 | 11000/19752 batches | lr 0.00 | ms/batch 375.04 | loss  0.86 | ppl     2.37
# | epoch   4 | 11200/19752 batches | lr 0.00 | ms/batch 375.19 | loss  0.87 | ppl     2.38
# | epoch   4 | 11400/19752 batches | lr 0.00 | ms/batch 375.21 | loss  0.86 | ppl     2.37
# | epoch   4 | 11600/19752 batches | lr 0.00 | ms/batch 375.35 | loss  0.86 | ppl     2.37
# | epoch   4 | 11800/19752 batches | lr 0.00 | ms/batch 374.95 | loss  0.86 | ppl     2.36
# | epoch   4 | 12000/19752 batches | lr 0.00 | ms/batch 376.36 | loss  0.86 | ppl     2.36
# saved model
# | epoch   4 | 12200/19752 batches | lr 0.00 | ms/batch 383.05 | loss  0.86 | ppl     2.36
# | epoch   4 | 12400/19752 batches | lr 0.00 | ms/batch 374.76 | loss  0.86 | ppl     2.36
# | epoch   4 | 12600/19752 batches | lr 0.00 | ms/batch 375.02 | loss  0.87 | ppl     2.38
# | epoch   4 | 12800/19752 batches | lr 0.00 | ms/batch 374.78 | loss  0.86 | ppl     2.37
# | epoch   4 | 13000/19752 batches | lr 0.00 | ms/batch 374.74 | loss  0.87 | ppl     2.38
# | epoch   4 | 13200/19752 batches | lr 0.00 | ms/batch 374.98 | loss  0.87 | ppl     2.38
# | epoch   4 | 13400/19752 batches | lr 0.00 | ms/batch 375.63 | loss  0.86 | ppl     2.37
# | epoch   4 | 13600/19752 batches | lr 0.00 | ms/batch 375.22 | loss  0.86 | ppl     2.37
# | epoch   4 | 13800/19752 batches | lr 0.00 | ms/batch 375.31 | loss  0.87 | ppl     2.38
# | epoch   4 | 14000/19752 batches | lr 0.00 | ms/batch 374.71 | loss  0.87 | ppl     2.38
# saved model
# | epoch   4 | 14200/19752 batches | lr 0.00 | ms/batch 384.05 | loss  0.86 | ppl     2.37
# | epoch   4 | 14400/19752 batches | lr 0.00 | ms/batch 375.25 | loss  0.86 | ppl     2.37
# | epoch   4 | 14600/19752 batches | lr 0.00 | ms/batch 375.72 | loss  0.87 | ppl     2.38
# | epoch   4 | 14800/19752 batches | lr 0.00 | ms/batch 375.47 | loss  0.87 | ppl     2.38
# | epoch   4 | 15000/19752 batches | lr 0.00 | ms/batch 375.51 | loss  0.86 | ppl     2.36
# | epoch   4 | 15200/19752 batches | lr 0.00 | ms/batch 374.75 | loss  0.86 | ppl     2.37
# | epoch   4 | 15400/19752 batches | lr 0.00 | ms/batch 375.71 | loss  0.86 | ppl     2.37
# | epoch   4 | 15600/19752 batches | lr 0.00 | ms/batch 374.79 | loss  0.87 | ppl     2.38
# | epoch   4 | 15800/19752 batches | lr 0.00 | ms/batch 375.80 | loss  0.86 | ppl     2.36
# | epoch   4 | 16000/19752 batches | lr 0.00 | ms/batch 374.78 | loss  0.86 | ppl     2.36
# saved model
# | epoch   4 | 16200/19752 batches | lr 0.00 | ms/batch 383.91 | loss  0.86 | ppl     2.37
# | epoch   4 | 16400/19752 batches | lr 0.00 | ms/batch 376.02 | loss  0.86 | ppl     2.36
# | epoch   4 | 16600/19752 batches | lr 0.00 | ms/batch 376.14 | loss  0.87 | ppl     2.38
# | epoch   4 | 16800/19752 batches | lr 0.00 | ms/batch 376.19 | loss  0.86 | ppl     2.37
# | epoch   4 | 17000/19752 batches | lr 0.00 | ms/batch 375.36 | loss  0.87 | ppl     2.38
# | epoch   4 | 17200/19752 batches | lr 0.00 | ms/batch 375.74 | loss  0.86 | ppl     2.37
# | epoch   4 | 17400/19752 batches | lr 0.00 | ms/batch 375.74 | loss  0.87 | ppl     2.38
# | epoch   4 | 17600/19752 batches | lr 0.00 | ms/batch 375.51 | loss  0.87 | ppl     2.38
# | epoch   4 | 17800/19752 batches | lr 0.00 | ms/batch 375.14 | loss  0.87 | ppl     2.39
# | epoch   4 | 18000/19752 batches | lr 0.00 | ms/batch 376.26 | loss  0.87 | ppl     2.38
# saved model
# | epoch   4 | 18200/19752 batches | lr 0.00 | ms/batch 383.79 | loss  0.86 | ppl     2.37
# | epoch   4 | 18400/19752 batches | lr 0.00 | ms/batch 375.81 | loss  0.86 | ppl     2.36
# | epoch   4 | 18600/19752 batches | lr 0.00 | ms/batch 375.36 | loss  0.87 | ppl     2.39
# | epoch   4 | 18800/19752 batches | lr 0.00 | ms/batch 375.71 | loss  0.87 | ppl     2.39
# | epoch   4 | 19000/19752 batches | lr 0.00 | ms/batch 375.73 | loss  0.87 | ppl     2.39
# | epoch   4 | 19200/19752 batches | lr 0.00 | ms/batch 375.20 | loss  0.87 | ppl     2.39
# | epoch   4 | 19400/19752 batches | lr 0.00 | ms/batch 375.62 | loss  0.87 | ppl     2.40
# | epoch   4 | 19600/19752 batches | lr 0.00 | ms/batch 375.65 | loss  0.87 | ppl     2.39
# got batch of size torch.Size([383, 12, 3]), skipping
# skipping sample eval because of shape: torch.Size([340, 6, 3])
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 7694.46s | valid loss  0.93 | valid ppl     2.54
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/19752 batches | lr 0.00 | ms/batch 377.80 | loss  0.86 | ppl     2.35
# | epoch   5 |   400/19752 batches | lr 0.00 | ms/batch 375.26 | loss  0.85 | ppl     2.35
# | epoch   5 |   600/19752 batches | lr 0.00 | ms/batch 376.00 | loss  0.86 | ppl     2.37
# | epoch   5 |   800/19752 batches | lr 0.00 | ms/batch 375.47 | loss  0.85 | ppl     2.34
# | epoch   5 |  1000/19752 batches | lr 0.00 | ms/batch 376.81 | loss  0.85 | ppl     2.33
# | epoch   5 |  1200/19752 batches | lr 0.00 | ms/batch 375.89 | loss  0.85 | ppl     2.34
# | epoch   5 |  1400/19752 batches | lr 0.00 | ms/batch 375.04 | loss  0.85 | ppl     2.35
# | epoch   5 |  1600/19752 batches | lr 0.00 | ms/batch 375.41 | loss  0.85 | ppl     2.35
# | epoch   5 |  1800/19752 batches | lr 0.00 | ms/batch 376.57 | loss  0.86 | ppl     2.36
# | epoch   5 |  2000/19752 batches | lr 0.00 | ms/batch 376.19 | loss  0.86 | ppl     2.36
# saved model
# | epoch   5 |  2200/19752 batches | lr 0.00 | ms/batch 383.52 | loss  0.85 | ppl     2.33
# | epoch   5 |  2400/19752 batches | lr 0.00 | ms/batch 375.72 | loss  0.86 | ppl     2.36
# | epoch   5 |  2600/19752 batches | lr 0.00 | ms/batch 376.33 | loss  0.86 | ppl     2.36
# | epoch   5 |  2800/19752 batches | lr 0.00 | ms/batch 375.83 | loss  0.86 | ppl     2.36
# | epoch   5 |  3000/19752 batches | lr 0.00 | ms/batch 375.49 | loss  0.85 | ppl     2.34
# | epoch   5 |  3200/19752 batches | lr 0.00 | ms/batch 376.30 | loss  0.85 | ppl     2.34
# | epoch   5 |  3400/19752 batches | lr 0.00 | ms/batch 376.20 | loss  0.85 | ppl     2.35
# | epoch   5 |  3600/19752 batches | lr 0.00 | ms/batch 375.71 | loss  0.86 | ppl     2.36
# | epoch   5 |  3800/19752 batches | lr 0.00 | ms/batch 374.87 | loss  0.85 | ppl     2.34
# | epoch   5 |  4000/19752 batches | lr 0.00 | ms/batch 376.32 | loss  0.85 | ppl     2.35
# saved model
# | epoch   5 |  4200/19752 batches | lr 0.00 | ms/batch 383.71 | loss  0.86 | ppl     2.36
# | epoch   5 |  4400/19752 batches | lr 0.00 | ms/batch 375.82 | loss  0.85 | ppl     2.34
# | epoch   5 |  4600/19752 batches | lr 0.00 | ms/batch 375.40 | loss  0.86 | ppl     2.35
# | epoch   5 |  4800/19752 batches | lr 0.00 | ms/batch 375.20 | loss  0.85 | ppl     2.35
# | epoch   5 |  5000/19752 batches | lr 0.00 | ms/batch 377.07 | loss  0.86 | ppl     2.37
# | epoch   5 |  5200/19752 batches | lr 0.00 | ms/batch 375.30 | loss  0.85 | ppl     2.34
# | epoch   5 |  5400/19752 batches | lr 0.00 | ms/batch 375.26 | loss  0.85 | ppl     2.34
# | epoch   5 |  5600/19752 batches | lr 0.00 | ms/batch 376.38 | loss  0.85 | ppl     2.35
# | epoch   5 |  5800/19752 batches | lr 0.00 | ms/batch 375.18 | loss  0.86 | ppl     2.37
# | epoch   5 |  6000/19752 batches | lr 0.00 | ms/batch 375.69 | loss  0.85 | ppl     2.34
# saved model
# | epoch   5 |  6200/19752 batches | lr 0.00 | ms/batch 383.49 | loss  0.85 | ppl     2.33
# | epoch   5 |  6400/19752 batches | lr 0.00 | ms/batch 375.32 | loss  0.85 | ppl     2.35
# | epoch   5 |  6600/19752 batches | lr 0.00 | ms/batch 375.68 | loss  0.86 | ppl     2.35
# | epoch   5 |  6800/19752 batches | lr 0.00 | ms/batch 374.94 | loss  0.85 | ppl     2.35
# | epoch   5 |  7000/19752 batches | lr 0.00 | ms/batch 374.74 | loss  0.85 | ppl     2.34
# | epoch   5 |  7200/19752 batches | lr 0.00 | ms/batch 374.87 | loss  0.85 | ppl     2.34
# | epoch   5 |  7400/19752 batches | lr 0.00 | ms/batch 374.90 | loss  0.85 | ppl     2.35
# | epoch   5 |  7600/19752 batches | lr 0.00 | ms/batch 375.12 | loss  0.85 | ppl     2.34
# | epoch   5 |  7800/19752 batches | lr 0.00 | ms/batch 375.61 | loss  0.85 | ppl     2.33
# | epoch   5 |  8000/19752 batches | lr 0.00 | ms/batch 375.20 | loss  0.85 | ppl     2.35
# saved model
# | epoch   5 |  8200/19752 batches | lr 0.00 | ms/batch 382.83 | loss  0.85 | ppl     2.34
# | epoch   5 |  8400/19752 batches | lr 0.00 | ms/batch 376.09 | loss  0.86 | ppl     2.35
# | epoch   5 |  8600/19752 batches | lr 0.00 | ms/batch 376.24 | loss  0.85 | ppl     2.35
# | epoch   5 |  8800/19752 batches | lr 0.00 | ms/batch 376.44 | loss  0.86 | ppl     2.35
# | epoch   5 |  9000/19752 batches | lr 0.00 | ms/batch 375.18 | loss  0.85 | ppl     2.33
# | epoch   5 |  9200/19752 batches | lr 0.00 | ms/batch 375.94 | loss  0.86 | ppl     2.36
# | epoch   5 |  9400/19752 batches | lr 0.00 | ms/batch 375.45 | loss  0.85 | ppl     2.35
# | epoch   5 |  9600/19752 batches | lr 0.00 | ms/batch 375.41 | loss  0.85 | ppl     2.34
# | epoch   5 |  9800/19752 batches | lr 0.00 | ms/batch 375.67 | loss  0.85 | ppl     2.35
# | epoch   5 | 10000/19752 batches | lr 0.00 | ms/batch 375.83 | loss  0.85 | ppl     2.35
# saved model
# | epoch   5 | 10200/19752 batches | lr 0.00 | ms/batch 383.45 | loss  0.86 | ppl     2.36
# | epoch   5 | 10400/19752 batches | lr 0.00 | ms/batch 375.45 | loss  0.86 | ppl     2.35
# | epoch   5 | 10600/19752 batches | lr 0.00 | ms/batch 376.01 | loss  0.86 | ppl     2.37
# | epoch   5 | 10800/19752 batches | lr 0.00 | ms/batch 375.59 | loss  0.86 | ppl     2.35
# | epoch   5 | 11000/19752 batches | lr 0.00 | ms/batch 375.69 | loss  0.86 | ppl     2.36
# | epoch   5 | 11200/19752 batches | lr 0.00 | ms/batch 375.11 | loss  0.86 | ppl     2.37
# | epoch   5 | 11400/19752 batches | lr 0.00 | ms/batch 375.27 | loss  0.86 | ppl     2.36
# | epoch   5 | 11600/19752 batches | lr 0.00 | ms/batch 375.73 | loss  0.86 | ppl     2.36
# | epoch   5 | 11800/19752 batches | lr 0.00 | ms/batch 375.16 | loss  0.85 | ppl     2.35
# | epoch   5 | 12000/19752 batches | lr 0.00 | ms/batch 375.57 | loss  0.85 | ppl     2.35
# saved model
# | epoch   5 | 12200/19752 batches | lr 0.00 | ms/batch 383.00 | loss  0.86 | ppl     2.35
# | epoch   5 | 12400/19752 batches | lr 0.00 | ms/batch 375.68 | loss  0.85 | ppl     2.35
# | epoch   5 | 12600/19752 batches | lr 0.00 | ms/batch 375.41 | loss  0.86 | ppl     2.37
# | epoch   5 | 12800/19752 batches | lr 0.00 | ms/batch 375.14 | loss  0.86 | ppl     2.36
# | epoch   5 | 13000/19752 batches | lr 0.00 | ms/batch 375.93 | loss  0.86 | ppl     2.37
# | epoch   5 | 13200/19752 batches | lr 0.00 | ms/batch 375.69 | loss  0.86 | ppl     2.37
# | epoch   5 | 13400/19752 batches | lr 0.00 | ms/batch 376.00 | loss  0.86 | ppl     2.36
# | epoch   5 | 13600/19752 batches | lr 0.00 | ms/batch 375.83 | loss  0.86 | ppl     2.36
# | epoch   5 | 13800/19752 batches | lr 0.00 | ms/batch 375.72 | loss  0.86 | ppl     2.37
# | epoch   5 | 14000/19752 batches | lr 0.00 | ms/batch 375.66 | loss  0.86 | ppl     2.37
# saved model
# | epoch   5 | 14200/19752 batches | lr 0.00 | ms/batch 382.87 | loss  0.86 | ppl     2.36
# | epoch   5 | 14400/19752 batches | lr 0.00 | ms/batch 374.78 | loss  0.86 | ppl     2.36
# | epoch   5 | 14600/19752 batches | lr 0.00 | ms/batch 375.13 | loss  0.86 | ppl     2.36
# | epoch   5 | 14800/19752 batches | lr 0.00 | ms/batch 374.95 | loss  0.86 | ppl     2.37
# | epoch   5 | 15000/19752 batches | lr 0.00 | ms/batch 375.57 | loss  0.86 | ppl     2.35
# | epoch   5 | 15200/19752 batches | lr 0.00 | ms/batch 375.67 | loss  0.86 | ppl     2.36
# | epoch   5 | 15400/19752 batches | lr 0.00 | ms/batch 376.47 | loss  0.86 | ppl     2.36
# | epoch   5 | 15600/19752 batches | lr 0.00 | ms/batch 376.43 | loss  0.86 | ppl     2.37
# | epoch   5 | 15800/19752 batches | lr 0.00 | ms/batch 375.07 | loss  0.85 | ppl     2.35
# | epoch   5 | 16000/19752 batches | lr 0.00 | ms/batch 375.27 | loss  0.86 | ppl     2.35
# saved model
# | epoch   5 | 16200/19752 batches | lr 0.00 | ms/batch 383.15 | loss  0.86 | ppl     2.36
# | epoch   5 | 16400/19752 batches | lr 0.00 | ms/batch 375.80 | loss  0.85 | ppl     2.35
# | epoch   5 | 16600/19752 batches | lr 0.00 | ms/batch 375.52 | loss  0.86 | ppl     2.37
# | epoch   5 | 16800/19752 batches | lr 0.00 | ms/batch 376.21 | loss  0.86 | ppl     2.37
# | epoch   5 | 17000/19752 batches | lr 0.00 | ms/batch 375.48 | loss  0.86 | ppl     2.36
# | epoch   5 | 17200/19752 batches | lr 0.00 | ms/batch 375.65 | loss  0.86 | ppl     2.36
# | epoch   5 | 17400/19752 batches | lr 0.00 | ms/batch 375.25 | loss  0.86 | ppl     2.37
# | epoch   5 | 17600/19752 batches | lr 0.00 | ms/batch 375.81 | loss  0.86 | ppl     2.37
# | epoch   5 | 17800/19752 batches | lr 0.00 | ms/batch 375.33 | loss  0.87 | ppl     2.38
# | epoch   5 | 18000/19752 batches | lr 0.00 | ms/batch 375.90 | loss  0.86 | ppl     2.37
# saved model
# | epoch   5 | 18200/19752 batches | lr 0.00 | ms/batch 383.81 | loss  0.86 | ppl     2.36
# | epoch   5 | 18400/19752 batches | lr 0.00 | ms/batch 375.71 | loss  0.85 | ppl     2.35
# | epoch   5 | 18600/19752 batches | lr 0.00 | ms/batch 375.21 | loss  0.86 | ppl     2.37
# | epoch   5 | 18800/19752 batches | lr 0.00 | ms/batch 375.50 | loss  0.87 | ppl     2.38
# | epoch   5 | 19000/19752 batches | lr 0.00 | ms/batch 375.35 | loss  0.87 | ppl     2.38
# | epoch   5 | 19200/19752 batches | lr 0.00 | ms/batch 376.28 | loss  0.87 | ppl     2.38
# | epoch   5 | 19400/19752 batches | lr 0.00 | ms/batch 376.49 | loss  0.87 | ppl     2.38
# | epoch   5 | 19600/19752 batches | lr 0.00 | ms/batch 376.60 | loss  0.87 | ppl     2.38
# got batch of size torch.Size([383, 12, 3]), skipping
# skipping sample eval because of shape: torch.Size([340, 6, 3])
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 7699.77s | valid loss  0.93 | valid ppl     2.55
# -----------------------------------------------------------------------------------------
# | epoch   6 |   200/19752 batches | lr 0.00 | ms/batch 378.25 | loss  0.85 | ppl     2.34
# | epoch   6 |   400/19752 batches | lr 0.00 | ms/batch 376.30 | loss  0.85 | ppl     2.34
# | epoch   6 |   600/19752 batches | lr 0.00 | ms/batch 376.28 | loss  0.86 | ppl     2.37
# | epoch   6 |   800/19752 batches | lr 0.00 | ms/batch 376.89 | loss  0.84 | ppl     2.33
# | epoch   6 |  1000/19752 batches | lr 0.00 | ms/batch 376.36 | loss  0.84 | ppl     2.33
# | epoch   6 |  1200/19752 batches | lr 0.00 | ms/batch 377.00 | loss  0.85 | ppl     2.33
# | epoch   6 |  1400/19752 batches | lr 0.00 | ms/batch 375.84 | loss  0.85 | ppl     2.34
# | epoch   6 |  1600/19752 batches | lr 0.00 | ms/batch 376.64 | loss  0.85 | ppl     2.34
# | epoch   6 |  1800/19752 batches | lr 0.00 | ms/batch 376.47 | loss  0.85 | ppl     2.34
# | epoch   6 |  2000/19752 batches | lr 0.00 | ms/batch 376.93 | loss  0.85 | ppl     2.35
# saved model
# | epoch   6 |  2200/19752 batches | lr 0.00 | ms/batch 384.98 | loss  0.84 | ppl     2.33
# | epoch   6 |  2400/19752 batches | lr 0.00 | ms/batch 376.65 | loss  0.86 | ppl     2.35
# | epoch   6 |  2600/19752 batches | lr 0.00 | ms/batch 376.89 | loss  0.85 | ppl     2.35
# | epoch   6 |  2800/19752 batches | lr 0.00 | ms/batch 376.30 | loss  0.85 | ppl     2.35
# | epoch   6 |  3000/19752 batches | lr 0.00 | ms/batch 377.30 | loss  0.85 | ppl     2.33
# | epoch   6 |  3200/19752 batches | lr 0.00 | ms/batch 376.08 | loss  0.85 | ppl     2.33
# | epoch   6 |  3400/19752 batches | lr 0.00 | ms/batch 376.39 | loss  0.85 | ppl     2.34
# | epoch   6 |  3600/19752 batches | lr 0.00 | ms/batch 377.69 | loss  0.86 | ppl     2.35
# | epoch   6 |  3800/19752 batches | lr 0.00 | ms/batch 376.73 | loss  0.85 | ppl     2.33
# | epoch   6 |  4000/19752 batches | lr 0.00 | ms/batch 376.47 | loss  0.85 | ppl     2.34
# saved model
# | epoch   6 |  4200/19752 batches | lr 0.00 | ms/batch 385.10 | loss  0.85 | ppl     2.35
# | epoch   6 |  4400/19752 batches | lr 0.00 | ms/batch 376.32 | loss  0.85 | ppl     2.34
# | epoch   6 |  4600/19752 batches | lr 0.00 | ms/batch 376.25 | loss  0.85 | ppl     2.34
# | epoch   6 |  4800/19752 batches | lr 0.00 | ms/batch 376.59 | loss  0.85 | ppl     2.34
# | epoch   6 |  5000/19752 batches | lr 0.00 | ms/batch 376.33 | loss  0.86 | ppl     2.36
# | epoch   6 |  5200/19752 batches | lr 0.00 | ms/batch 376.56 | loss  0.85 | ppl     2.33
# | epoch   6 |  5400/19752 batches | lr 0.00 | ms/batch 375.90 | loss  0.85 | ppl     2.34
# | epoch   6 |  5600/19752 batches | lr 0.00 | ms/batch 376.54 | loss  0.85 | ppl     2.34
# | epoch   6 |  5800/19752 batches | lr 0.00 | ms/batch 376.16 | loss  0.86 | ppl     2.36
# | epoch   6 |  6000/19752 batches | lr 0.00 | ms/batch 376.43 | loss  0.84 | ppl     2.33
# saved model
# | epoch   6 |  6200/19752 batches | lr 0.00 | ms/batch 385.73 | loss  0.84 | ppl     2.33
# | epoch   6 |  6400/19752 batches | lr 0.00 | ms/batch 376.84 | loss  0.85 | ppl     2.34
# | epoch   6 |  6600/19752 batches | lr 0.00 | ms/batch 376.35 | loss  0.85 | ppl     2.34
# | epoch   6 |  6800/19752 batches | lr 0.00 | ms/batch 376.41 | loss  0.85 | ppl     2.34
# | epoch   6 |  7000/19752 batches | lr 0.00 | ms/batch 376.51 | loss  0.84 | ppl     2.33
# | epoch   6 |  7200/19752 batches | lr 0.00 | ms/batch 376.37 | loss  0.85 | ppl     2.33
# | epoch   6 |  7400/19752 batches | lr 0.00 | ms/batch 377.05 | loss  0.85 | ppl     2.34
# | epoch   6 |  7600/19752 batches | lr 0.00 | ms/batch 376.53 | loss  0.85 | ppl     2.33
# | epoch   6 |  7800/19752 batches | lr 0.00 | ms/batch 377.19 | loss  0.84 | ppl     2.32
# | epoch   6 |  8000/19752 batches | lr 0.00 | ms/batch 375.91 | loss  0.85 | ppl     2.34
# saved model
# | epoch   6 |  8200/19752 batches | lr 0.00 | ms/batch 383.26 | loss  0.84 | ppl     2.33
# | epoch   6 |  8400/19752 batches | lr 0.00 | ms/batch 375.64 | loss  0.85 | ppl     2.35
# | epoch   6 |  8600/19752 batches | lr 0.00 | ms/batch 376.34 | loss  0.85 | ppl     2.34
# | epoch   6 |  8800/19752 batches | lr 0.00 | ms/batch 376.18 | loss  0.85 | ppl     2.34
# | epoch   6 |  9000/19752 batches | lr 0.00 | ms/batch 376.57 | loss  0.84 | ppl     2.32
# | epoch   6 |  9200/19752 batches | lr 0.00 | ms/batch 376.91 | loss  0.85 | ppl     2.35
# | epoch   6 |  9400/19752 batches | lr 0.00 | ms/batch 376.50 | loss  0.85 | ppl     2.34
# | epoch   6 |  9600/19752 batches | lr 0.00 | ms/batch 376.33 | loss  0.85 | ppl     2.33
# | epoch   6 |  9800/19752 batches | lr 0.00 | ms/batch 376.10 | loss  0.85 | ppl     2.34
# | epoch   6 | 10000/19752 batches | lr 0.00 | ms/batch 376.33 | loss  0.85 | ppl     2.34
# saved model
# | epoch   6 | 10200/19752 batches | lr 0.00 | ms/batch 384.19 | loss  0.85 | ppl     2.35
# | epoch   6 | 10400/19752 batches | lr 0.00 | ms/batch 376.43 | loss  0.85 | ppl     2.34
# | epoch   6 | 10600/19752 batches | lr 0.00 | ms/batch 377.47 | loss  0.86 | ppl     2.36
# | epoch   6 | 10800/19752 batches | lr 0.00 | ms/batch 376.31 | loss  0.85 | ppl     2.34
# | epoch   6 | 11000/19752 batches | lr 0.00 | ms/batch 376.04 | loss  0.85 | ppl     2.35
# | epoch   6 | 11200/19752 batches | lr 0.00 | ms/batch 376.77 | loss  0.86 | ppl     2.36
# | epoch   6 | 11400/19752 batches | lr 0.00 | ms/batch 377.45 | loss  0.86 | ppl     2.35
# | epoch   6 | 11600/19752 batches | lr 0.00 | ms/batch 376.12 | loss  0.85 | ppl     2.35
# | epoch   6 | 11800/19752 batches | lr 0.00 | ms/batch 376.97 | loss  0.85 | ppl     2.34
# | epoch   6 | 12000/19752 batches | lr 0.00 | ms/batch 376.75 | loss  0.85 | ppl     2.34
# saved model
# | epoch   6 | 12200/19752 batches | lr 0.00 | ms/batch 383.47 | loss  0.85 | ppl     2.34
# | epoch   6 | 12400/19752 batches | lr 0.00 | ms/batch 376.82 | loss  0.85 | ppl     2.34
# | epoch   6 | 12600/19752 batches | lr 0.00 | ms/batch 375.80 | loss  0.86 | ppl     2.36
# | epoch   6 | 12800/19752 batches | lr 0.00 | ms/batch 376.19 | loss  0.85 | ppl     2.35
# | epoch   6 | 13000/19752 batches | lr 0.00 | ms/batch 376.89 | loss  0.86 | ppl     2.36
# | epoch   6 | 13200/19752 batches | lr 0.00 | ms/batch 376.80 | loss  0.86 | ppl     2.36
# | epoch   6 | 13400/19752 batches | lr 0.00 | ms/batch 376.18 | loss  0.85 | ppl     2.35
# | epoch   6 | 13600/19752 batches | lr 0.00 | ms/batch 375.70 | loss  0.85 | ppl     2.35
# | epoch   6 | 13800/19752 batches | lr 0.00 | ms/batch 376.22 | loss  0.86 | ppl     2.36
# | epoch   6 | 14000/19752 batches | lr 0.00 | ms/batch 376.68 | loss  0.86 | ppl     2.36
# saved model
# | epoch   6 | 14200/19752 batches | lr 0.00 | ms/batch 384.62 | loss  0.86 | ppl     2.35
# | epoch   6 | 14400/19752 batches | lr 0.00 | ms/batch 376.37 | loss  0.86 | ppl     2.36
# | epoch   6 | 14600/19752 batches | lr 0.00 | ms/batch 376.72 | loss  0.86 | ppl     2.35
# | epoch   6 | 14800/19752 batches | lr 0.00 | ms/batch 376.37 | loss  0.86 | ppl     2.35
# | epoch   6 | 15000/19752 batches | lr 0.00 | ms/batch 376.19 | loss  0.85 | ppl     2.34
# | epoch   6 | 15200/19752 batches | lr 0.00 | ms/batch 375.74 | loss  0.85 | ppl     2.35
# | epoch   6 | 15400/19752 batches | lr 0.00 | ms/batch 376.33 | loss  0.86 | ppl     2.36
# | epoch   6 | 15600/19752 batches | lr 0.00 | ms/batch 376.43 | loss  0.86 | ppl     2.36
# | epoch   6 | 15800/19752 batches | lr 0.00 | ms/batch 375.51 | loss  0.85 | ppl     2.34
# | epoch   6 | 16000/19752 batches | lr 0.00 | ms/batch 376.25 | loss  0.85 | ppl     2.34
# saved model
# | epoch   6 | 16200/19752 batches | lr 0.00 | ms/batch 382.97 | loss  0.85 | ppl     2.35
# | epoch   6 | 16400/19752 batches | lr 0.00 | ms/batch 375.94 | loss  0.85 | ppl     2.34
# | epoch   6 | 16600/19752 batches | lr 0.00 | ms/batch 376.08 | loss  0.86 | ppl     2.36
# | epoch   6 | 16800/19752 batches | lr 0.00 | ms/batch 375.89 | loss  0.86 | ppl     2.35
# | epoch   6 | 17000/19752 batches | lr 0.00 | ms/batch 376.49 | loss  0.86 | ppl     2.35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-1c236699687a> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'best_val_loss = float("inf")\nepochs = 40 # The number of epochs\nbest_model = None\n\nmodel.cuda()\n\nfor epoch in range(1, epochs + 1):\n    epoch_start_time = time.time()\n    train()\n    val_loss = evaluate(model, val_data_post)\n    print(\'-\' * 89)\n    print(\'| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | \'\n          \'valid ppl {:8.2f}\'.format(epoch, (time.time() - epoch_start_time),\n                                     val_loss, math.exp(val_loss)))\n    print(\'-\' * 89)\n\n    if val_loss < best_val_loss:\n        best_val_loss = val_loss\n        best_model = model\n        with open(\'heb_char_model.pkl\', \'wb\') as f:\n            torch.save(model, f)\n\n    scheduler.step()')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-53> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-6-f8e5dcc24e10> in train()
#     173             print('got batch of size {0}, skipping'.format(data.shape))
#     174             continue
# --> 175         output = model(data, src_mask)
#     176         loss = criterion(output.view(-1, ntokens), targets)
#     177         loss.backward()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-6-f8e5dcc24e10> in forward(self, data, src_mask)
#     106         src = torch.cat((src, meta2.unsqueeze(2)), 2)
#     107         # multi-head transformer
# --> 108         output = self.transformer_encoder(src, src_mask)
#     109         # fully connected linear
#     110         output = self.decoder(output)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/transformer.py in forward(self, src, mask, src_key_padding_mask)
#     179
#     180         for mod in self.layers:
# --> 181             output = mod(output, src_mask=mask, src_key_padding_mask=src_key_padding_mask)
#     182
#     183         if self.norm is not None:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/transformer.py in forward(self, src, src_mask, src_key_padding_mask)
#     292         """
#     293         src2 = self.self_attn(src, src, src, attn_mask=src_mask,
# --> 294                               key_padding_mask=src_key_padding_mask)[0]
#     295         src = src + self.dropout1(src2)
#     296         src = self.norm1(src)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/activation.py in forward(self, query, key, value, key_padding_mask, need_weights, attn_mask)
#     983                 training=self.training,
#     984                 key_padding_mask=key_padding_mask, need_weights=need_weights,
# --> 985                 attn_mask=attn_mask)
#     986
#     987
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v)
#    4142
#    4143     if not use_separate_proj_weight:
# -> 4144         if torch.equal(query, key) and torch.equal(key, value):
#    4145             # self-attention
#    4146             q, k, v = linear(query, in_proj_weight, in_proj_bias).chunk(3, dim=-1)
#
# KeyboardInterrupt:

# %%
model = torch.load('saved_models/heb_char_model_style.pkl')

# %%
label_dict
# Out:
# {';כלכלה עולמית': 11,
#  'בריאות וחינוך': 2,
#  'כדורגל': 7,
#  'כלכלה ישראל': 6,
#  'כלכלה עולמית': 3,
#  'כללי': 4,
#  'משפט ופלילי': 1,
#  'סקס': 9,
#  'סקס ויחסים': 10,
#  'פוליטי': 5,
#  'פלסטינים': 8,
#  'צבאי': 0}

# %%
model.eval() # Turn on the evaluation mode

# ['צבאי', 'משפט ופלילי', 'בריאות וחינוך', 'כלכלה עולמית', 'כללי', 'פוליטי'
# 'כלכלה ישראל', 'כדורגל', 'פלסטינים', 'סקס', 'סקס ויחסים', ';כלכלה עולמית']
genre = label_dict['פוליטי']
# genre = label_dict['כללי']
timestamp = 1

start_string = """נשיא המדינה"""
# start_string = """איש העסקים האמריקאי"""
# start_string = """שר הכדורגל ויו"ר התאגדות המנופאים"""
# start_string = """איך תדעי אם השותף שלך אוהב אותך?"""
# start_string = """ תושב כפר סבא חשוד כי סחר בחמוסים"""
# start_string = """[SOS] מחסור בחמאה בעקבות שביתה בנמל [SEP1] ברחבי הארץ הורגש מחסור חמור בחמאה לקראת חג הפסח [SEP2] """
# start_string = """הרשות הפלסטינית תחלק ממתקים למתנחלים לכבוד פסח"""
start_string = '[SOS] ' + start_string
# start_string = '[SOS] ' + start_string + ' [SEP1]'


generated_text = ''
with torch.no_grad():
    generated = generate(model, vocab, start_string, genre, timestamp, 1, 500)
for char in generated:
    generated_text += char
print(generated_text)
print(' ')
# Out:
# [SOS]נשיא המדינה התפטר מתפקידו [SEP1]נשיא המדינה התפטר מתפקידו כנשיא המדינה. הוא הודיע על התפטרותו מתפקידו כנשיא המדינה [SEP2]נשיא המדינה, משה קצב, הודיע היום (יום ג') על התפטרותו מתפקידו. קצב הודיע על התפטרותו מתפקידו כנשיא המדינה. קצב הודיע על התפטרותו מתפקידו כנשיא המדינה. קצב הודיע על התפטרותו מתפקידו כנשיא המדינה. קצב הודיע על התפטרותו מתפקידו כנשיא המדינה. קצב הודיע על התפטרותו מתפקידו כנשיא המדינה. קצב הודיע על התפטרותו מתפקידו כנשיא המדינה. קצב הודיע על התפטרותו מתפקידו כנשיא המדינה. קצב הודיע על הת

# %%
genres = data.label.unique()

start_string_list = [
                     """ראש הממשלה""",
                     """נתינהו:""",
                     """שר הבריאות""",
                     """גאווה ישראלית""",
                     """משואה לתקומה""",
                     """הישג אדיר""",
                     """התפתחות מפתיעה""",
                     """מועצת החכמים""",
                     """איגוד יצרני""",
                     """מפכ"ל המשטרה:""",
                     """שר הביטחון:""",
                     """ירידות חדות""",
                     """זינוק""",
                     """נשיא המדינה""",
                     """השרים אישרו""",
                     """הקבינט התכנס""",
                     """מה קרה""",
                     """מי גנב""",
                     """מה קורה""",
                     """אלף ימים""",
                     """עלייתו ונפילתו""",
                     """אזהרה: """,
                     """אין גבול""",
                     """המלחמה נמשכת:""",
                     """דווקא אחרי""",
                     """ראש המל"ל""",
                     """עשרות חמוסים""",
                     """קרב צמוד בין""",
                     """תגלית מפתיעה""",
]

# %%
year
# Out:
# 600

# %%
import datetime

# %%
# %%time
generated_articles = []
for start_string in start_string_list:
    start_string = '[SOS] ' + start_string
    for label in genres:
        genre = label_dict[label]
        year = random.randint(0,21) * 100
        month = random.randint(0,12)
        day = random.randint(0,29)
        timestamp = year + month
        generated_text = ''
        with torch.no_grad():
            generated = generate(model, vocab, start_string, genre, timestamp, 1, 512)
        for char in generated:
            generated_text += char

        title = generated_text.split('[SEP1]')[0].strip('[SOS] ')
        try:
            sub_title = generated_text.split('[SEP1]')[1].split('[SEP2]')[0].strip('[SEP1] ')
        except IndexError:
            sub_title = ''
        try:
            body = generated_text.split('[SEP1]')[1].split('[SEP2]')[1].strip('[SEP2]')
        except IndexError:
            body = ''

        tilte = title.replace('ynet', 'whynet')
        sub_tilte = title.replace('ynet', 'whynet')
        body = title.replace('ynet', 'whynet')

        generated_articles.append((start_string, genre, "{0}.{1}.{2}"\
                                   .format(day, month, (year // 100) + 2000) ,\
                                   title, sub_title, body))
# Out:
# CPU times: user 1h 13min 32s, sys: 2min 31s, total: 1h 16min 4s
# Wall time: 38min 7s

# %%
new_list = []
for i in range(0, len(generated_articles)):
    new_list.append([item for item in generated_articles[i]])

# %%
new_list
# Out:
# [['[SOS] ראש הממשלה',
#   0,
#   '13.1.2017',
#   'ראש הממשלה התייחס למתיחות בין ישראל לחמאס',
#   'בנימין נתניהו התייחס למתיחות בין ישראל לחמאס בעקבות הפיגוע בירושלים ואמר כי "ישראל תקפה באיראן באמצעות מטוסי קרב וכלי טיס של צה"ל". הוא הוסיף כי "האיראנים מתחילים להתמודד עם המתיחות בין ישראל לחמאס"',
#   'ראש הממשלה התייחס למתיחות בין ישראל לחמאס'],
#  ['[SOS] ראש הממשלה',
#   1,
#   '29.5.2015',
#   'ראש הממשלה לשעבר אהוד אולמרט נחקר בפרשת הולילנד',
#   'המשטרה חקרה את ראש הממשלה לשעבר בפרשת הולילנד. הוא חשוד בעבירות שוחד, מרמה והפרת אמונים. החקירה נפתחה בעקבות תלונה שהגישה המשטרה נגדו',
#   'ראש הממשלה לשעבר אהוד אולמרט נחקר בפרשת הולילנד'],
#  ['[SOS] ראש הממשלה',
#   2,
#   '17.2.2013',
#   'ראש הממשלה הודיע על הקמת ועדת חקירה',
#   'במהלך דיון בוועדת החינוך של הכנסת הודיע ראש הממשלה כי הוא מתנגד להקמת ועדת חקירה ממלכתית לבדיקת התנהלות המורים במשבר הקואליציוני. הוא הודיע כי הוא מתנגד להקמת ועדת חקירה ממלכתית',
#   'ראש הממשלה הודיע על הקמת ועדת חקירה'],
#  ['[SOS] ראש הממשלה',
#   3,
#   '23.11.2015',
#   'ראש הממשלה היוצא של ארה"ב התפטר',
#   'לאחר שהודיע על התפטרותו מתפקיד המנכ"ל החדש, הודיע היום ראש הממשלה היוצא, ג',
#   'ראש הממשלה היוצא של ארה"ב התפטר'],
#  ['[SOS] ראש הממשלה',
#   4,
#   '18.11.2017',
#   'ראש הממשלה בנימין נתניהו התפטר מתפקידו',
#   'במהלך השבוע האחרון הודיע נתניהו כי הוא מתפטר מתפקידו כראש הממשלה בעקבות החלטת הממשלה להעביר את המינוי לתפקיד השר לביטחון פנים. במקביל, הודיע נתניהו כי הוא מתפטר מתפקידו כשר הביטחון',
#   'ראש הממשלה בנימין נתניהו התפטר מתפקידו'],
#  ['[SOS] ראש הממשלה',
#   5,
#   '5.9.2017',
#   'ראש הממשלה בנימין נתניהו נפגש עם השר לשעבר',
#   'בפגישה עם השר לשעבר הוא נפגש עם השר לשעבר והשניים התקשו להתמודד עם המשבר הכלכלי הקשה שפקד אותו בימים האחרונים. השניים התקשו להתמודד עם המשבר הכלכלי הקשה שפקד אותו בימים האחרונים',
#   'ראש הממשלה בנימין נתניהו נפגש עם השר לשעבר'],
#  ['[SOS] ראש הממשלה',
#   6,
#   '21.1.2021',
#   'ראש הממשלה הודיע על הקמת ועדה לבחינת המיסוי על הדלק',
#   'הוועדה המוניטרית של בנק ישראל הודיעה כי היא מתכוונת להקים ועדה שתבחן את המיסוי על הדלק והמזון במשק במקרה של התייקרות הנפט בעולם. הוועדה תבחן את המיסוי על הדלק והמזון במשק במקרה של התייקרות הנפט',
#   'ראש הממשלה הודיע על הקמת ועדה לבחינת המיסוי על הדלק'],
#  ['[SOS] ראש הממשלה',
#   7,
#   '5.2.2018',
#   'ראש הממשלה הבא של ארגנטינה',
#   'המאמן הארגנטינאי יחליף את האלביסלסטה בתפקיד המנכ"ל הבא של המועדון ב-2018. המאמן החדש יהיה המאמן הבא של המועדון',
#   'ראש הממשלה הבא של ארגנטינה'],
#  ['[SOS] ראש הממשלה',
#   8,
#   '4.3.2000',
#   'ראש הממשלה הפלסטיני בעזה: "המצב ברצועה יימשך"',
#   'בראיון לעיתון "אל-חיאת" אמר ראש הממשלה הפלסטיני כי המצב ברצועה יימשך גם בשנה הבאה. לדבריו, המצב ברצועה יימשך גם בשנה הבאה',
#   'ראש הממשלה הפלסטיני בעזה: "המצב ברצועה יימשך"'],
#  ['[SOS] ראש הממשלה',
#   9,
#   '14.5.2000',
#   'ראש הממשלה הנוכחי מתנגד להסכם המסגרת',
#   'האם הסכם המסגרת בין האוצר להסתדרות יחזיר את המסגרת למדינה? האם הסכם המסגרת יחזיר את המסגרת למדינה הנוכחית?',
#   'ראש הממשלה הנוכחי מתנגד להסכם המסגרת'],
#  ['[SOS] ראש הממשלה',
#   10,
#   '17.12.2001',
#   'ראש הממשלה הנוכחי מתחיל להתערב במשבר',
#   'האם המשבר הכלכלי בארה"ב מתחיל להתערב? האם המשבר הכלכלי בארה"ב מתחיל להתערב?',
#   'ראש הממשלה הנוכחי מתחיל להתערב במשבר'],
#  ['[SOS] ראש הממשלה',
#   11,
#   '16.1.2021',
#   'ראש הממשלה הבא שלך',
#   'את מתחילה להתרגל למציאות הזאת ולא להיות בממשלה הבאה. את מתחילה להתרגל למציאות הזאת ולא להיות בממשלה הבאה. את מתחילה להתרגל למציאות הזאת ולא להיות בממשלה הבאה. את מתחילה להתרגל למציאות הזאת ולא להיות בממשלה הבאה',
#   'ראש הממשלה הבא שלך'],
#  ['[SOS] נתינהו:',
#   0,
#   '5.12.2021',
#   'נתינהו: "איראן מנסה להגן על עצמה מפני התקיפה בסוריה"',
#   'ראש הממשלה התייחס לתקיפה הישראלית בסוריה בלילה שבין שישי לשבת בסוריה ואמר כי "איראן מנסה להגן על עצמה מפני התקפה ישראלית בסוריה". על התקיפה בסוריה: "איראן מנסה להגן על עצמה מפני התקפה ישראלית"',
#   'נתינהו: "איראן מנסה להגן על עצמה מפני התקיפה בסוריה"'],
#  ['[SOS] נתינהו:',
#   1,
#   '0.10.2004',
#   'נתינהו: "המשטרה לא מתכוונת להתערב במינוי המפכ"ל"',
#   'בעקבות החלטת המשטרה למנות את המפכ"ל הבא של המשטרה, אמר ניצב דודי כהן, כי המשטרה לא מתכוונת להתערב במינוי המפכ"ל הבא של המשטרה. "המשטרה לא מתכוונת להתערב במינוי המפכ"ל הבא", אמר כהן',
#   'נתינהו: "המשטרה לא מתכוונת להתערב במינוי המפכ"ל"'],
#  ['[SOS] נתינהו:',
#   2,
#   '5.11.2000',
#   'נתינהו: "הממשלה מתנהגת כמו בית ספר בעולם"',
#   'ראש הממשלה התייחס למצב הביטחוני במדינות המערב, ואמר כי "הממשלה מתנהגת כמו בית ספר בעולם". במקביל, הוא הוסיף כי "הממשלה מתנהגת כמו בית ספר בעולם"',
#   'נתינהו: "הממשלה מתנהגת כמו בית ספר בעולם"'],
#  ['[SOS] נתינהו:',
#   3,
#   '22.8.2003',
#   'נתינהו: הממשלה תתערב במחירי הנפט',
#   'הממשלה תתערב במחירי הנפט ותתערב במחירי הנפט',
#   'נתינהו: הממשלה תתערב במחירי הנפט'],
#  ['[SOS] נתינהו:',
#   4,
#   '20.9.2012',
#   'נתינהו: "המדינה לא מתערבת במשבר הדיור"',
#   'ראש הממשלה התייחס למשבר הדיור במגזר הערבי ואמר כי המדינה לא מתערבת במשבר הדיור. "המדינה לא מתערבת במשבר הדיור", אמר נתניהו בטקס הממלכתי בהר הרצל. "המדינה לא מתערבת במשבר הדיור"',
#   'נתינהו: "המדינה לא מתערבת במשבר הדיור"'],
#  ['[SOS] נתינהו:',
#   5,
#   '19.11.2000',
#   'נתינהו: "אני מתנצל על המשבר הכלכלי"',
#   'במפלגת העבודה מתכוונים להתנצל על המשבר הכלכלי הקשה במפלגת העבודה, ולהתנצל על המשבר הכלכלי הקשה במפלגת העבודה. במפלגה מתכוונים להתנצל על המשבר הכלכלי הקשה במפלגה',
#   'נתינהו: "אני מתנצל על המשבר הכלכלי"'],
#  ['[SOS] נתינהו:',
#   6,
#   '15.9.2011',
#   'נתינהו: "הממשלה מתנהלת בצורה מורכבת"',
#   'ראש הממשלה התייחס למשבר הכלכלי העולמי ואמר כי הממשלה מתנהלת בצורה מורכבת מהמדיניות הכלכלית של הממשלה ומהמצב הביטחוני. "הממשלה מתנהלת בצורה מורכבת מהמצב הביטחוני והמדיני ומהמצב הביטחוני והמדיני"',
#   'נתינהו: "הממשלה מתנהלת בצורה מורכבת"'],
#  ['[SOS] נתינהו:',
#   7,
#   '15.8.2013',
#   'נתינהו: "אני מרוצה מההחלטה שלי"',
#   'המאמן הישראלי התייחס להחלטת המאמן הישראלי להתפטר מתפקידו כמאמן הקבוצה: "אני מרוצה מההחלטה שלי"',
#   'נתינהו: "אני מרוצה מההחלטה שלי"'],
#  ['[SOS] נתינהו:',
#   8,
#   '19.0.2007',
#   'נתינהו: הפלסטינים מתנגדים להסכם הפיוס',
#   'בכיר החמאס אמר כי הפלסטינים מתנגדים להסכם הפיוס בין הפתח לחמאס, ומציע להם להתנגד להסכם הפיוס בין הפתח לחמאס. לדבריו, ההסכם יביא להסכם הפיוס בין הפתח לחמאס',
#   'נתינהו: הפלסטינים מתנגדים להסכם הפיוס'],
#  ['[SOS] נתינהו:',
#   9,
#   '4.12.2000',
#   'נתינהו: המשפחה המודרנית מתחילה להתאבד',
#   'המשפחה המודרנית מתחילה להתאבד בעקבות המקרה המוזר של המשפחה המודרנית שהתאבדה במלון "פארק" בתל אביב. המשפחה המודרנית מתחילה להתאבד בעקבות המקרה',
#   'נתינהו: המשפחה המודרנית מתחילה להתאבד'],
#  ['[SOS] נתינהו:',
#   10,
#   '10.2.2014',
#   'נתינהו: האם הוא מתחיל להתחיל להתגרש?',
#   'האם הוא מתחיל להתגרש מהמשפחה שלו? האם הוא מתחיל להתגרש מהמשפחה שלו? האם הוא מתחיל להתגרש מהמשפחה שלו?',
#   'נתינהו: האם הוא מתחיל להתחיל להתגרש?'],
#  ['[SOS] נתינהו:',
#   11,
#   '2.8.2019',
#   'נתינהו: אני מתחילה להתאהב בכל הזמן',
#   'אני מתחילה להתאהב בכל הזמן בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני מתחילה להתאהב בכל הזמן. אני',
#   'נתינהו: אני מתחילה להתאהב בכל הזמן'],
#  ['[SOS] שר הבריאות',
#   0,
#   '10.5.2000',
#   'שר הבריאות הפלסטיני הורה להפסיק את הירי',
#   'בעקבות הפיגוע במושב בית ענון הורה שר הבריאות הפלסטיני, יעקב בן יזרי, להפסיק את הירי לעבר המושב בית ענון שבשומרון. בן יזרי הורה להפסיק את הירי לעבר המושב בית ענון',
#   'שר הבריאות הפלסטיני הורה להפסיק את הירי'],
#  ['[SOS] שר הבריאות',
#   1,
#   '19.0.2011',
#   'שר הבריאות לשעבר הורשע במרמה והפרת אמונים',
#   'בית המשפט המחוזי בתל-אביב הרשיע את שר הבריאות לשעבר במרמה והפרת אמונים ובעבירות של מרמה והפרת אמונים. השופט הרשיע אותו בעבירות של מרמה והפרת אמונים וקבלת דבר במרמה בנסיבות מחמירות',
#   'שר הבריאות לשעבר הורשע במרמה והפרת אמונים'],
#  ['[SOS] שר הבריאות',
#   2,
#   '9.1.2019',
#   'שר הבריאות הודיע על הקמת ועדת חקירה לבדיקת התאונות הקטלניות',
#   'השר הודיע כי הוועדה תתכנס ביום ראשון לדיון בהצעת החוק של ח"כ איילת שקד להקמת ועדת חקירה לבדיקת התאונות הקטלניות בכבישים. הוועדה תדון בהצעה של שקד להקמת ועדת חקירה לבדיקת התאונות הקטלניות בכבישים',
#   'שר הבריאות הודיע על הקמת ועדת חקירה לבדיקת התאונות הקטלניות'],
#  ['[SOS] שר הבריאות',
#   3,
#   '26.5.2019',
#   'שר הבריאות היוצא אובמה מתנגד להצעת החוק להגבלת שכר הבכירים',
#   'השר אובמה מתנגד להצעת החוק של החברות הציבוריות להגבלת שכר הבכירים בחברות הציבוריות והביטוח הפנסיוני. ההצעה תוגש בימים הקרובים לאישור הממשלה',
#   'שר הבריאות היוצא אובמה מתנגד להצעת החוק להגבלת שכר הבכירים'],
#  ['[SOS] שר הבריאות',
#   4,
#   '24.7.2008',
#   'שר הבריאות הורה להקים ועדת חקירה לבדיקת האסון',
#   'השר הורה להקים ועדת חקירה לבדיקת האסון בנחל צפית בעקבות התרסקות מטוס הקרב בנחל צפית. הוועדה המליצה להקים ועדת חקירה לבדיקת האסון',
#   'שר הבריאות הורה להקים ועדת חקירה לבדיקת האסון'],
#  ['[SOS] שר הבריאות',
#   5,
#   '29.11.2019',
#   'שר הבריאות לשעבר נגד הממשלה: "לא ניתן להעביר את המסר"',
#   'בריאיון לאולפן ynet התייחס שר הבריאות להחלטת הממשלה להעביר את המסר למשרד הבריאות לאחר שהממשלה הודיעה כי תעביר את המסר למשרד הבריאות: "אני מתנגד להעברת המסר למשרד הבריאות". על ההחלטה להעביר את המסר למשרד הבריאות: "אני מתנגד להעברת המסר למשרד הבריאות"',
#   'שר הבריאות לשעבר נגד הממשלה: "לא ניתן להעביר את המסר"'],
#  ['[SOS] שר הבריאות',
#   6,
#   '2.2.2011',
#   'שר הבריאות החדש: "הממשלה תתערב בשוק העבודה"',
#   'שר הבריאות החדש הודיע כי הממשלה תתערב בשוק העבודה בשוק העבודה בשוק העבודה. "הממשלה תתערב בשוק העבודה בשוק העבודה בשוק העבודה בשוק העבודה בשוק העבודה בשוק העבודה בשנים הקרובות", אמר שר האוצר',
#   'שר הבריאות החדש: "הממשלה תתערב בשוק העבודה"'],
#  ['[SOS] שר הבריאות',
#   7,
#   '6.11.2016',
#   'שר הבריאות האיטלקי: "אני מאושר מהמשחקים האחרונים"',
#   'השוער האיטלקי הוותיק (34) התייחס למשחק הגומלין מול אינטר במוקדמות ליגת האלופות (ג',
#   'שר הבריאות האיטלקי: "אני מאושר מהמשחקים האחרונים"'],
#  ['[SOS] שר הבריאות',
#   8,
#   '7.10.2015',
#   'שר הבריאות הפלסטיני הודיע על הקמת מדינה פלסטינית',
#   'השר הפלסטיני הודיע כי הוא מתכוון להקים מדינה פלסטינית בגבולות 67',
#   'שר הבריאות הפלסטיני הודיע על הקמת מדינה פלסטינית'],
#  ['[SOS] שר הבריאות',
#   9,
#   '17.7.2017',
#   'שר הבריאות החדש של האמת',
#   'האמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהא',
#   'שר הבריאות החדש של האמת'],
#  ['[SOS] שר הבריאות',
#   10,
#   '23.11.2012',
#   'שר הבריאות החדש: האם הוא מתחיל להתאבד?',
#   'האם הוא מתחיל להתאבד במשך שנים או שניים מהם מתחיל להתאבד? האם הוא מתחיל להתאבד במשך שנים או שניים מהם מתחיל להתאבד? האם הוא מתחיל להתאבד במשך שנים?',
#   'שר הבריאות החדש: האם הוא מתחיל להתאבד?'],
#  ['[SOS] שר הבריאות',
#   11,
#   '22.9.2001',
#   'שר הבריאות המינית מתעקש: האם היא מתנהגת בצורה מינית?',
#   'השר המיני מתעקש שהיא מתנהגת בצורה מינית ומתנהגת בצורה מינית ומינית, ומתעקש שהיא מתנהגת בצורה מינית ומינית. השר המיני מתעקש שהיא מתנהגת בצורה מינית ומינית ומתנהגת בצורה מינית ומינית',
#   'שר הבריאות המינית מתעקש: האם היא מתנהגת בצורה מינית?'],
#  ['[SOS] גאווה ישראלית',
#   0,
#   '10.0.2017',
#   'גאווה ישראלית בעולם: "המדינה הזו מתנהגת כמו במלחמה"',
#   'במלחמת העצמאות השתתפו בין היתר בני משפחת גאווה לבין משפחת גאווה שנרצחה בפיגוע בערד. "המדינה הזו מתנהגת כמו במלחמה הבאה", אמר אחיו של גאווה שנרצח בפיגוע בערד. "המדינה הזו מתנהגת כמו במלחמה הבאה"',
#   'גאווה ישראלית בעולם: "המדינה הזו מתנהגת כמו במלחמה"'],
#  ['[SOS] גאווה ישראלית',
#   1,
#   '6.3.2008',
#   'גאווה ישראלית במקום העבודה במקום העבודה',
#   'במקום העבודה במקום העבודה במקום העבודה במקום העבודה במקום העבודה, הופיעו במקום העבודה במקום העבודה במקום העבודה. במקום העבודה במקום העבודה במקום העבודה במקום העבודה',
#   'גאווה ישראלית במקום העבודה במקום העבודה'],
#  ['[SOS] גאווה ישראלית',
#   2,
#   '5.11.2003',
#   'גאווה ישראלית במקום ה-11 בעולם בתחום החינוך',
#   'הגאווה הישראלית במקום ה-11 בעולם בתחום החינוך הישראלי. המקום ה-11 בעולם בתחום החינוך הישראלי בתחום החינוך הישראלי בתחום החינוך הישראלי בתחום החינוך הישראלי בתחום החינוך הישראלי בתחום החינוך הישראלי',
#   'גאווה ישראלית במקום ה-11 בעולם בתחום החינוך'],
#  ['[SOS] גאווה ישראלית',
#   3,
#   '25.7.2014',
#   'גאווה ישראלית באירופה: המדינות החברות באירופה',
#   'המדינות החברות באיחוד האירופי התחייבו להעניק למדינות החברות באיחוד האירופי הטבות מס בהיקף של כ-100 מיליארד אירו לשנה, במטרה להגביר את התחרותיות באירופה ובארה"ב',
#   'גאווה ישראלית באירופה: המדינות החברות באירופה'],
#  ['[SOS] גאווה ישראלית',
#   4,
#   '20.4.2015',
#   'גאווה ישראלית במקום ה-12 בעולם',
#   'המדינה השיגה את המקום ה-12 בעולם במקום ה-12 בעולם במקום ה-12 בעולם במקום ה-12. המדינה השיגה את המקום ה-12 בעולם במקום ה-12 בעולם במקום ה-12 בעולם במקום ה-12. המדינה השיגה את המקום ה-12 בעולם במקום ה-12 בעולם במקום ה-12 במקום ה-12 בעולם במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-12 במקום ה-',
#   'גאווה ישראלית במקום ה-12 בעולם'],
#  ['[SOS] גאווה ישראלית',
#   5,
#   '23.6.2009',
#   'גאווה ישראלית בירושלים: "המדינה לא מתערבת"',
#   'במשרד הפנים מתכוונים להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות להעניק למדינה את הסמכות',
#   'גאווה ישראלית בירושלים: "המדינה לא מתערבת"'],
#  ['[SOS] גאווה ישראלית',
#   6,
#   '20.11.2016',
#   'גאווה ישראלית למדינות ה-OECD: "המדינות המפותחות יישארו בידינו"',
#   'במסגרת הדיונים בין הארגונים הכלכליים למדינות ה-OECD על הצמיחה במשק הישראלי, הוחלט כי המדינות המפותחות יישארו בידי המדינות המפותחות בעולם ויישארו בידי המדינות המפותחות. הארגונים הכלכליים מתנגדים להצעה להגדיל את התקציב ב-2.5%',
#   'גאווה ישראלית למדינות ה-OECD: "המדינות המפותחות יישארו בידינו"'],
#  ['[SOS] גאווה ישראלית',
#   7,
#   '18.5.2017',
#   'גאווה ישראלית במונדיאל הנשים',
#   'המאמן הישראלי הודיע כי הוא מתכוון להציע לנשים הרות במונדיאל הנשים ברוסיה ולהציע להן להתגייס לצבא במקום להיות מוכרות במונדיאל הנשים',
#   'גאווה ישראלית במונדיאל הנשים'],
#  ['[SOS] גאווה ישראלית',
#   8,
#   '24.8.2006',
#   'גאווה ישראלית בעזה: "המצב הזה לא יכול להיות"',
#   'ברצועה מתכוננים למצב הקשה ברצועה, אבל ברצועה מתכוננים למצב הקשה ברצועה. ברצועה מתכוננים למצב הקשה ברצועה, ומבטיחים להתמודד עם המצב הביטחוני הקשה ברצועה',
#   'גאווה ישראלית בעזה: "המצב הזה לא יכול להיות"'],
#  ['[SOS] גאווה ישראלית',
#   9,
#   '2.4.2007',
#   'גאווה ישראלית במיוחד: המילים האלה',
#   'המילים האלה הן המילים האלה המילים האלה המילים האלה הן המילים האלה המילים האלה המילים האלה הן המילים האלה המילים האלה המילים האלה הן המילים האלה המילים האלה המילים האלה הן המילים האלה המילים האלה הן המילים האלה המילים האלה הן המילים האלה המילים האלה הן המילים האלה המילים האלה הן המילים האלה המילים האלה הן המילים האלה המילים האלה הן המילים האלה המילים האלה הן המילים האלה המילים האלה המילים האלה הן המילים האלה המילים האלה המילים האלה הן המילים האלה המילים האלה',
#   'גאווה ישראלית במיוחד: המילים האלה'],
#  ['[SOS] גאווה ישראלית',
#   10,
#   '18.5.2005',
#   'גאווה ישראלית בעיני המצלמות: האם הן מתחילות להתגרש?',
#   'האם הן מתחילות להתגרש מהמצלמות המיניות של המצלמות המיניות של המצלמות המיניות של המצלמות המיניות? האם הן מתחילות להתגרש מהמצלמות המיניות של המצלמות המיניות של המצלמות המיניות? האם הן מתחילות להתגרש מהמצלמות המיניות של המצלמות המיניות?',
#   'גאווה ישראלית בעיני המצלמות: האם הן מתחילות להתגרש?'],
#  ['[SOS] גאווה ישראלית',
#   11,
#   '8.6.2012',
#   'גאווה ישראלית במיטה: האם היא מתחילה להתגרש?',
#   'האם היא מתחילה להתגרש מהמיטה הזוגית שלה? האם היא מתחילה להתגרש מהמיטה הזוגית שלה? האם היא מתחילה להתגרש מהמיטה הזוגית שלה? האם היא מתחילה להתגרש מהמיטה הזוגית שלה?',
#   'גאווה ישראלית במיטה: האם היא מתחילה להתגרש?'],
#  ['[SOS] משואה לתקומה',
#   0,
#   '6.5.2002',
#   'משואה לתקומה בירושלים: "המדינה מתנגדת להסדר"',
#   'המדינה הודיעה כי היא מתנגדת להסדר הקבע בין המדינה לבין המדינה בעניין הסדר הקבע בין המדינה לבין המדינה. המדינה תבקש להוציא צו המורה למדינה להסדיר את התנאים המגבילים להסדר הקבע בין המדינה לבין המדינה',
#   'משואה לתקומה בירושלים: "המדינה מתנגדת להסדר"'],
#  ['[SOS] משואה לתקומה',
#   1,
#   '20.3.2019',
#   'משואה לתקומה בירושלים: "המשטרה מתנהגת כמו במקום בו היא מתגוררת"',
#   'במשטרה מתכוונים להגיש כתב אישום נגד החשוד בהתעללות בילדים בני 10 עד 12. המשואה התקיימה ביום שישי בבירה. המשואה התקיימה ביום שישי בבית המשפט השלום בירושלים. המשואה התקיימה ביום שישי בבית המשפט המחוזי בירושלים. המשואה התקיימה ביום שישי בבית המשפט המחוזי בירושלים',
#   'משואה לתקומה בירושלים: "המשטרה מתנהגת כמו במקום בו היא מתגוררת"'],
#  ['[SOS] משואה לתקומה',
#   2,
#   '16.2.2007',
#   'משואה לתקומה בבית הספר: "הילדים לא יודעים"',
#   'בית הספר היסודי "אורט גולד" בקריית גת הוא המשואה המתוכננת להיום בבית הספר היסודי "אורט גולד" בקריית גת. המורים מתכוונים להשבית את הלימודים במוסדות החינוך במחאה על החלטת הממשלה להקפיא את הלימודים במוסדות החינוך במוסדות החינוך',
#   'משואה לתקומה בבית הספר: "הילדים לא יודעים"'],
#  ['[SOS] משואה לתקומה',
#   3,
#   '16.3.2008',
#   'משואה לתקומה בארה"ב: הכלכלה התכווצה ב-0.1%',
#   'הכלכלה הגדולה בעולם התכווצה ב-0.1% ברבעון הראשון של 2008, לאחר שהתכווצה ב-0.4% ברבעון הראשון. התחזיות המוקדמות דיברו על צמיחה של 0.1% בלבד ברבעון הראשון',
#   'משואה לתקומה בארה"ב: הכלכלה התכווצה ב-0.1%'],
#  ['[SOS] משואה לתקומה',
#   4,
#   '5.4.2019',
#   'משואה לתקומה בירושלים: "המדינה מתנהגת כמו בירושלים"',
#   'בירושלים התקיימה הערב הצבעה על הצעת החוק של ח"כ אורן חזן להקמת מדינה פלסטינית. "המדינה מתנהגת כמו בירושלים", אמר חזן במשדר המיוחד באולפן ynet. חזן: "המדינה מתנהגת כמו בירושלים"',
#   'משואה לתקומה בירושלים: "המדינה מתנהגת כמו בירושלים"'],
#  ['[SOS] משואה לתקומה',
#   5,
#   '26.7.2016',
#   'משואה לתקומה ביום הבחירות: "המפלגות החרדיות מתנגדות להצעה"',
#   'המפלגות החרדיות התכנסו לישיבה מיוחדת במטרה להגיע להסכמות על הקמת ממשלת אחדות. המפלגות החרדיות התכנסו לישיבה מיוחדת במטרה להגיע להסכמות על הקמת ממשלת אחדות. המפלגות החרדיות התכנסו לישיבה מיוחדת במטרה להגיע להסכמות על הקמת ממשלת אחדות',
#   'משואה לתקומה ביום הבחירות: "המפלגות החרדיות מתנגדות להצעה"'],
#  ['[SOS] משואה לתקומה',
#   6,
#   '9.5.2021',
#   'משואה לתקומה ביוון: "המדינה מתנהגת כמו ביוון"',
#   'המדינה מתכוונת להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הזדמנות להעניק ליוון הז',
#   'משואה לתקומה ביוון: "המדינה מתנהגת כמו ביוון"'],
#  ['[SOS] משואה לתקומה',
#   7,
#   '11.9.2000',
#   'משואה לתקומה באיטליה: 10 מיליון אירו לרומא',
#   'המאמן האיטלקי הודיע כי הוא מתכוון להציע לרומא את הכסף שישלם לרומא',
#   'משואה לתקומה באיטליה: 10 מיליון אירו לרומא'],
#  ['[SOS] משואה לתקומה',
#   8,
#   '3.1.2015',
#   'משואה לתקומה בעזה: "המצב הכלכלי הקשה ברצועה הוא הפתרון המוסרי"',
#   'ברצועה מתכוננים למצב הכלכלי הקשה ברצועה ולהתמודדות עם המשבר הכלכלי הקשה ברצועה. בעזה מתכוננים למצב הקשה ברצועה ובעזה מאשימים את ישראל בהתפתחויות במשבר הפוליטי. "המצב הכלכלי הקשה ברצועה הוא הפתרון המוסרי של המצב הכלכלי ברצועה"',
#   'משואה לתקומה בעזה: "המצב הכלכלי הקשה ברצועה הוא הפתרון המוסרי"'],
#  ['[SOS] משואה לתקומה',
#   9,
#   '0.4.2009',
#   'משואה לתקומה במיטה: האם היא מתחילה להתעלם?',
#   'האם היא מתחילה להתעלם מהמצב הקשה במיטה ומהמצב הקשה במיטה, או שמא היא מתחילה להתעלם מהמצב הקשה במיטה? האם היא מתחילה להתעלם מהמצב הקשה במיטה ומהמצב הקשה במיטה?',
#   'משואה לתקומה במיטה: האם היא מתחילה להתעלם?'],
#  ['[SOS] משואה לתקומה',
#   10,
#   '17.8.2015',
#   'משואה לתקומה בלי להיות מומחה',
#   'היא מתחילה להתרגל למשואה לתקומה בלי להיות מומחית בתקומה בלי להיות מומחית בתקומה בלי להיות מומחית בתקומה בלי להיות מומחית בתקומה בלי להיות מומחה בתקומה בלי להיות מומחה בתקומה בלי להיות מומחה בתקומה בלי להיות מומחה בתקומה בלי להיות מומחה בתקומה בלי להיות מומחה בתקומה בלי להיות מומחה בתקומה',
#   'משואה לתקומה בלי להיות מומחה'],
#  ['[SOS] משואה לתקומה',
#   11,
#   '28.1.2009',
#   'משואה לתקומה במיטה: האם היא מתחילה להתגרש?',
#   'האם היא מתחילה להתגרש מהמיטה הזוגית שלה? האם היא מתחילה להתגרש מהמיטה הזוגית שלה? מדריך',
#   'משואה לתקומה במיטה: האם היא מתחילה להתגרש?'],
#  ['[SOS] הישג אדיר',
#   0,
#   '23.1.2010',
#   'הישג אדיר למשטרה: "המשטרה לא תפעל בעוד שנה"',
#   'במשטרה מעריכים כי המשטרה תפעל בעוד שנה נגד המשטרה והפרקליטות בפרשת הריגול העסקי. המשטרה תפעל בעוד שנה נגד המשטרה והפרקליטות בפרשה',
#   'הישג אדיר למשטרה: "המשטרה לא תפעל בעוד שנה"'],
#  ['[SOS] הישג אדיר',
#   1,
#   '26.8.2015',
#   'הישג אדיר למשטרה: "היא הייתה מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנ',
#   '',
#   'הישג אדיר למשטרה: "היא הייתה מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנה להיות מוכנ'],
#  ['[SOS] הישג אדיר',
#   2,
#   '15.3.2010',
#   'הישג אדיר למורים: "המורים לא יודעים מה קורה"',
#   'במשרד החינוך מתכוונים להודיע על השבתת הלימודים בכל התיכונים בשל המחאה החברתית. "המורים לא יודעים מה קורה במקום בו הם מתגוררים", אמר מנכ"ל משרד החינוך. "המורים לא יודעים מה קורה במקום בו הם מתגוררים"',
#   'הישג אדיר למורים: "המורים לא יודעים מה קורה"'],
#  ['[SOS] הישג אדיר',
#   3,
#   '19.12.2014',
#   'הישג אדיר למנהיגי העולם: האם המדינות העשירות יכולות להתמודד עם המשבר הכלכלי?',
#   'המדינות העשירות בעולם מתכוונות להתמודד עם המשבר הכלכלי הגלובלי, ולהתמודד עם המשבר הכלכלי הגלובלי. האם המדינות העשירות יכולות להתמודד עם המשבר הכלכלי הגלובלי?',
#   'הישג אדיר למנהיגי העולם: האם המדינות העשירות יכולות להתמודד עם המשבר הכלכלי?'],
#  ['[SOS] הישג אדיר',
#   4,
#   '19.11.2010',
#   'הישג אדיר למשפחות הנרצחים: "המדינה לא מתערבת"',
#   'במשפחות הנרצחים בפיגוע בירושלים מתקשים להתמודד עם המצב הביטחוני הקשה ביותר במזרח העיר. "המדינה לא מתערבת במצב הביטחוני ולא מתערבת במצב הביטחוני", אמר אביו של אחד הנרצחים. "המדינה לא מתערבת במצב הביטחוני"',
#   'הישג אדיר למשפחות הנרצחים: "המדינה לא מתערבת"'],
#  ['[SOS] הישג אדיר',
#   5,
#   '26.3.2016',
#   'הישג אדיר למפלגת העבודה: "אין לנו מושג מה היה קורה אם היינו מתנגדים לה"',
#   'במפלגת העבודה התקבלו במפלגת העבודה הודעות שלפיהן המפלגה תתמוך בהצעת החוק של ח"כ איתן כבל להקים מפלגה חדשה. "אין לנו מושג מה היה קורה אם היינו מתנגדים לה", אמר כבל. "אנחנו מתנגדים להצעה של כבל להקים מפלגה חדשה"',
#   'הישג אדיר למפלגת העבודה: "אין לנו מושג מה היה קורה אם היינו מתנגדים לה"'],
#  ['[SOS] הישג אדיר',
#   6,
#   '2.10.2003',
#   'הישג אדיר למשק הישראלי: מה יקרה אם יוריד את הריבית?',
#   'המשק הישראלי מתכוון להוריד את הריבית ב-0.25% לרמה של 4.25%; האינפלציה ב-2003 תסתכם ב-2.5% ותסתכם ב-2.5%',
#   'הישג אדיר למשק הישראלי: מה יקרה אם יוריד את הריבית?'],
#  ['[SOS] הישג אדיר',
#   7,
#   '6.7.2018',
#   "הישג אדיר למנצ'סטר סיטי במשחק הראשון",
#   'הקבוצה של פפ גווארדיולה הביסה 0:3 את ווסטהאם והשלימה 1:5 בסיכום שני המשחקים. המארחת הביסה 0:3 את ווסטהאם',
#   "הישג אדיר למנצ'סטר סיטי במשחק הראשון"],
#  ['[SOS] הישג אדיר',
#   8,
#   '20.3.2021',
#   'הישג אדיר לחמאס: "המצב הביטחוני בעזה - הפסקת אש"',
#   'בעקבות הפיגוע בירושלים וההסלמה בדרום, הודיע משרד הביטחון כי המצב הביטחוני ברצועה יימשך גם בימים הקרובים. בחמאס מתכוונים להגיב לירי הרקטות לעבר ישראל',
#   'הישג אדיר לחמאס: "המצב הביטחוני בעזה - הפסקת אש"'],
#  ['[SOS] הישג אדיר',
#   9,
#   '29.11.2020',
#   'הישג אדיר למשפחה של המורה שלך',
#   'הישג אדיר למשפחה שלך והיא מתחילה להתרגל למשפחה שלך ולהתחיל להתאהב בך. אני מתחילה להתאהב בך ובאמא שלך ולא מתחילה להתאהב בך. אני מתחילה להתאהב בך ובאמא שלך ולא מתחילה להתאהב בך ובאמא שלך ולא מתחילה להתאהב בך ובאמא שלך',
#   'הישג אדיר למשפחה של המורה שלך'],
#  ['[SOS] הישג אדיר',
#   10,
#   '18.1.2017',
#   'הישג אדיר לא מספיק להיות מודע למצב הזה',
#   'הישג אדיר לא מספיק להיות מודע למצב הזה. הישג אדיר לא מספיק להיות מודע למצב הזה. הישג אדיר לא מספיק להיות מודע למצב הזה. הישג אדיר לא מספיק להיות מודע למצב הזה',
#   'הישג אדיר לא מספיק להיות מודע למצב הזה'],
#  ['[SOS] הישג אדיר',
#   11,
#   '14.0.2019',
#   'הישג אדיר לא מספיק להיות מושלם',
#   'הישג אדיר לא מספיק להיות מושלם במיוחד במיוחד, אבל הישג אדיר לא מספיק להיות מושלם במיוחד. הישג אדיר לא מספיק להיות מושלם במיוחד במיוחד, והישג אדיר לא מספיק להיות מושלם במיוחד',
#   'הישג אדיר לא מספיק להיות מושלם'],
#  ['[SOS] התפתחות מפתיעה',
#   0,
#   '8.4.2002',
#   'התפתחות מפתיעה בפרשת המחבל המתאבד',
#   'במהלך החקירה נעצרו שני חשודים במעורבות בפיגוע במסעדת "סבארו" בתל אביב. המשטרה הצבאית החוקרת פתחה בחקירה',
#   'התפתחות מפתיעה בפרשת המחבל המתאבד'],
#  ['[SOS] התפתחות מפתיעה',
#   1,
#   '18.9.2020',
#   'התפתחות מפתיעה בפרשת הצוללות: המשטרה ממליצה להעמיד לדין את אלון חסן',
#   'המשטרה ממליצה להעמיד לדין את ראש העיר רמת השרון לשעבר בחשד לעבירות שוחד, מרמה והפרת אמונים. המשטרה ממליצה להעמיד לדין את חסן בעבירות שוחד, מרמה והפרת אמונים. המשטרה ממליצה להעמיד לדין את חסן בעבירות שוחד, מרמה והפרת אמונים',
#   'התפתחות מפתיעה בפרשת הצוללות: המשטרה ממליצה להעמיד לדין את אלון חסן'],
#  ['[SOS] התפתחות מפתיעה',
#   2,
#   '10.8.2003',
#   'התפתחות מפתיעה במשבר המורים',
#   'מורים בבתי הספר היסודיים ברחבי הארץ החלו להתפשט במהירות למשך שעתיים. במשרד החינוך מעריכים כי המשבר במערכת החינוך יימשך גם בימים הקרובים',
#   'התפתחות מפתיעה במשבר המורים'],
#  ['[SOS] התפתחות מפתיעה',
#   3,
#   '20.10.2017',
#   'התפתחות מפתיעה במשבר הכלכלי בארה"ב',
#   'המשבר הכלכלי בארה"ב הולך ומחריף: המשבר הכלכלי בארה"ב הולך ומחריף, והמשק האמריקני מתפשט למדינות אחרות. המשבר הכלכלי בארה"ב הולך ומחריף, והמשק האמריקני מתפשט למדינות אחרות',
#   'התפתחות מפתיעה במשבר הכלכלי בארה"ב'],
#  ['[SOS] התפתחות מפתיעה',
#   4,
#   '24.11.2002',
#   'התפתחות מפתיעה במצב הביטחוני בישראל',
#   'במשך שעות ארוכות ניסו המורים להתפשט למערכת החינוך בישראל. המשטרה מעריכה כי המצב הביטחוני בישראל הוא המשך התפשטות המחלה',
#   'התפתחות מפתיעה במצב הביטחוני בישראל'],
#  ['[SOS] התפתחות מפתיעה',
#   5,
#   '4.0.2010',
#   'התפתחות מפתיעה במשבר הדיור: "הממשלה מתעלמת"',
#   'במשבר הדיור הציבורי הולכים ומתרבים הסימנים להתפתחויות במשבר הדיור. במשרד השיכון מתכוונים להתערב במשבר הדיור הציבורי ולהתערב במשבר הדיור הציבורי. "הממשלה מתעלמת מהמצב הביטחוני ומהמצב הביטחוני", אמר יו"ר ההסתדרות',
#   'התפתחות מפתיעה במשבר הדיור: "הממשלה מתעלמת"'],
#  ['[SOS] התפתחות מפתיעה',
#   6,
#   '29.7.2008',
#   'התפתחות מפתיעה במצב המשק',
#   'המשק הישראלי צמח ברבעון השני ב-3.2% בהשוואה לרבעון המקביל אשתקד. התפתחות מפתיעה במצב המשק הישראלי במיתון במשק הישראלי ובמצב המשק הישראלי במיתון במשק',
#   'התפתחות מפתיעה במצב המשק'],
#  ['[SOS] התפתחות מפתיעה',
#   7,
#   '8.7.2017',
#   'התפתחות מפתיעה במשחק הידידות של ארגנטינה',
#   'המשחק הראשון בין הקבוצות במוקדמות המונדיאל בארגנטינה הסתיים ב-0:0 מאכזב מול אורוגוואי. המשחק הראשון בין הקבוצות הסתיים ב-0:0 מאכזב מול אורוגוואי',
#   'התפתחות מפתיעה במשחק הידידות של ארגנטינה'],
#  ['[SOS] התפתחות מפתיעה',
#   8,
#   '6.2.2000',
#   'התפתחות מפתיעה בפרשת המסמך המזויף',
#   'המשטרה הפלסטינית הודיעה כי היא מתכוונת להגיש כתב אישום נגד המעורבים בפרשה, בהם השר לשעבר גדעון עזרא. המשטרה הפלסטינית מתכוונת להגיש כתב אישום נגד המעורבים בפרשה',
#   'התפתחות מפתיעה בפרשת המסמך המזויף'],
#  ['[SOS] התפתחות מפתיעה',
#   9,
#   '5.0.2012',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיו',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד'],
#  ['[SOS] התפתחות מפתיעה',
#   10,
#   '11.11.2018',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיו',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד'],
#  ['[SOS] התפתחות מפתיעה',
#   11,
#   '3.7.2014',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיוחד במיו',
#   'התפתחות מפתיעה במיוחד במיוחד במיוחד'],
#  ['[SOS] מועצת החכמים',
#   0,
#   '7.7.2007',
#   'מועצת החכמים הודיעה: אין מיגון ביישובים',
#   'במסיבת עיתונאים שכינסה הודיעה המועצה האזורית חכמי התורה כי אין מיגון ביישובים המוגנים ביישובים המוגנים ביישובים המוגנים ביישובים המוגנים. המועצה האזורית חכמי התורה הודיעה כי אין מיגון ביישובים המוגנים ביישובים המוגנים',
#   'מועצת החכמים הודיעה: אין מיגון ביישובים'],
#  ['[SOS] מועצת החכמים',
#   1,
#   '16.8.2018',
#   'מועצת החכמים הודיעה: המשטרה תפתח בחקירה נגד המנכ"ל',
#   'במסגרת החקירה נגד המנכ"ל לשעבר של משרד החקלאות, שהודה במיוחס לו והורשע במסגרת הסדר טיעון בעבירות של מרמה והפרת אמונים, הלבנת הון ועבירות מס. המשטרה תפתח בחקירה נגד המנכ"ל לשעבר של משרד החקלאות',
#   'מועצת החכמים הודיעה: המשטרה תפתח בחקירה נגד המנכ"ל'],
#  ['[SOS] מועצת החכמים',
#   2,
#   '10.8.2002',
#   'מועצת החכמים החליטה: המורים ישביתו את הלימודים',
#   'המורים החליטו להשבית את הלימודים במוסדות החינוך ביישובים הערביים במחאה על החלטת הממשלה להשבית את הלימודים במוסדות החינוך ביישובים הערביים במחאה על החלטת הממשלה להשבית את הלימודים במוסדות החינוך ביישובים הערביים במחאה על החלטת הממשלה להשבית את הלימודים במוסדות החינוך ביישובים הערביים במחאה על החלטת הממשלה להשבית את הלימודים במוסדות החינוך ביישובים הערביים במחאה על החלטת הממשלה להשבית את הלימודים במוסדות החינוך ביישובים הערביים במחאה על החלטת הממש',
#   'מועצת החכמים החליטה: המורים ישביתו את הלימודים'],
#  ['[SOS] מועצת החכמים',
#   3,
#   '4.5.2000',
#   'מועצת החכמים של ארה"ב תתבע את המדינה',
#   'המועצה המחוקקת של ארה"ב הגישה תביעה נגד המדינה בטענה כי המדינה הפרה את חוקי התחרות',
#   'מועצת החכמים של ארה"ב תתבע את המדינה'],
#  ['[SOS] מועצת החכמים',
#   4,
#   '27.2.2015',
#   'מועצת החכמים הודיעה: נפתח מחדש המו"מ על הסכם השכר',
#   'המו"מ על הסכם השכר החדש בין האוצר להסתדרות נפתח במחאה על הסכם השכר החדש שנחתם בין ההסתדרות להסתדרות. המו"מ על הסכם השכר החדש נפתח בעקבות הפרסום ב-ynet',
#   'מועצת החכמים הודיעה: נפתח מחדש המו"מ על הסכם השכר'],
#  ['[SOS] מועצת החכמים',
#   5,
#   '25.2.2019',
#   'מועצת החכמים התכנסה לדיון במליאה על הקמת ועדת חקירה',
#   'המועצה האזורית חכמי התורה התכנסה לדיון במליאה על הקמת ועדת חקירה ממלכתית לבדיקת הקמת ועדת חקירה ממלכתית. המועצה האזורית חכמי התורה התכנסה לדיון במליאה על הקמת ועדת חקירה ממלכתית',
#   'מועצת החכמים התכנסה לדיון במליאה על הקמת ועדת חקירה'],
#  ['[SOS] מועצת החכמים',
#   6,
#   '13.12.2010',
#   'מועצת החכמים תתכנס לדיון בהצעת החוק להגבלת זכויות העובדים',
#   'הצעת החוק של ח"כ אורית נוקד מבקשת להגביל את זכויות העובדים בחברה במקום עבודתם של העובדים במקום עבודתם של העובדים במקום עבודתם של העובדים במקום עבודתם של העובדים במקום עבודתם של העובדים במקום עבודתם של העובדים במקום עבודתם של העובדים',
#   'מועצת החכמים תתכנס לדיון בהצעת החוק להגבלת זכויות העובדים'],
#  ['[SOS] מועצת החכמים',
#   7,
#   '15.12.2017',
#   'מועצת החכמים של האלופה הספרדית',
#   'המועדון הספרדי הודיע כי הוא מתכוון להציע לאלופת ספרד הצעה להחתים את החלוץ הארגנטינאי של הקבוצה הספרדית במקומו של אנטוניו קונטה שפוטר מהקבוצה בשנת 2015',
#   'מועצת החכמים של האלופה הספרדית'],
#  ['[SOS] מועצת החכמים',
#   8,
#   '6.0.2009',
#   'מועצת החכמים הודיעה: אין מנוס מהפינוי',
#   'בעקבות הפינוי המתוכנן של המאחז הבלתי חוקי בגוש קטיף, הודיעה המועצה האזורית שומרון כי אין מנוס מהפינוי. המועצה האזורית שומרון הודיעה כי אין מנוס מהפינוי',
#   'מועצת החכמים הודיעה: אין מנוס מהפינוי'],
#  ['[SOS] מועצת החכמים',
#   9,
#   '4.1.2009',
#   'מועצת החכמים של הפרויקט המיני בישראל',
#   'הפרויקט המיני של הפרויקט המיני בישראל מתקיים בימים אלה במסגרת המאבק בין הפרויקט לבין הממשלה המקומית בישראל. הפרויקט המיני בישראל מתקיים בימים אלה במסגרת המאבק בין הפרויקט לבין הממשלה המקומית',
#   'מועצת החכמים של הפרויקט המיני בישראל'],
#  ['[SOS] מועצת החכמים',
#   10,
#   '25.9.2005',
#   'מועצת החכמים הארצית: האם היא מתכוונת להתגרש?',
#   'האם היא מתכוונת להתגרש מהמועצה הארצית של החכמים הארצית ומהמועצה הארצית של החכמים הארצית? מומחית למשפט חוקתי מסבירה כי היא מתכוונת להתגרש מהמועצה הארצית של החכמים הארצית ומהמועצה הארצית של החכמים הארצית',
#   'מועצת החכמים הארצית: האם היא מתכוונת להתגרש?'],
#  ['[SOS] מועצת החכמים',
#   11,
#   '21.11.2018',
#   'מועצת החכמים של האמת',
#   'האמת של האמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת היא שהאמת הי',
#   'מועצת החכמים של האמת'],
#  ['[SOS] איגוד יצרני',
#   0,
#   '10.11.2010',
#   'איגוד יצרני הקוסמטיקה: "המדינה מתנהגת כאויב"',
#   'האיגוד הישראלי למען החייל החטוף הודיע כי הוא מתנגד להצעת החוק של ח"כ אורי אריאל להגביל את המשך המשא ומתן עם הפלסטינים במסגרת המאבק בין ישראל לרשות הפלסטינית. "המדינה מתנהגת כאויב מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מאוד מא',
#   'איגוד יצרני הקוסמטיקה: "המדינה מתנהגת כאויב"'],
#  ['[SOS] איגוד יצרני',
#   1,
#   '20.9.2005',
#   'איגוד יצרני הסמים בישראל מאיים לפגוע בעובדים זרים',
#   'האיגוד הישראלי למען הסמים בישראל מאיים לפגוע בעובדים זרים בישראל. האיגוד הישראלי למען הסמים בישראל מאיים לפגוע בעובדים זרים בישראל ובעובדים זרים בארץ',
#   'איגוד יצרני הסמים בישראל מאיים לפגוע בעובדים זרים'],
#  ['[SOS] איגוד יצרני',
#   2,
#   '11.12.2016',
#   'איגוד יצרני הסיגריות מאיים להשבית את הלימודים',
#   'האיגוד המקצועי של יצרני הסיגריות מאיים להשבית את הלימודים ביום ראשון הקרוב. האיגוד מאיים להשבית את הלימודים ביום ראשון הקרוב',
#   'איגוד יצרני הסיגריות מאיים להשבית את הלימודים'],
#  ['[SOS] איגוד יצרני',
#   3,
#   '11.4.2019',
#   'איגוד יצרני הרכב בארה"ב מאיים להשבית את המכירות',
#   'האיגוד המקצועי של יצרני הרכב בארה"ב הודיע כי המכירות יישארו סגורות במחצית השנייה של 2019, והמכירות יישארו סגורות במחצית השנייה של 2019',
#   'איגוד יצרני הרכב בארה"ב מאיים להשבית את המכירות'],
#  ['[SOS] איגוד יצרני',
#   4,
#   '10.7.2009',
#   'איגוד יצרני הסמים בישראל: "המדינה מתעלמת"',
#   'האיגוד הישראלי למען הסמים בישראל הודיע כי הוא מתנגד להצעת החוק של ח"כ אורי אריאל להגביל את הסמים בישראל. "המדינה מתעלמת מהמציאות הכלכלית של המדינה", אמר אריאל',
#   'איגוד יצרני הסמים בישראל: "המדינה מתעלמת"'],
#  ['[SOS] איגוד יצרני',
#   5,
#   '22.10.2011',
#   'איגוד יצרני המזון בישראל: "המדינה מתעלמת"',
#   'האיגוד הישראלי למזון ותרופות הודיע כי הוא מתנגד להצעת החוק של ח"כ אורי אריאל להגביל את המזון בישראל. "המדינה מתעלמת מהמציאות הכלכלית של המדינה", אמר אריאל',
#   'איגוד יצרני המזון בישראל: "המדינה מתעלמת"'],
#  ['[SOS] איגוד יצרני',
#   6,
#   '0.7.2005',
#   'איגוד יצרני המזון מקים קרן להשקעות בישראל',
#   'הקרן תקים קרן להשקעות בישראל בהשקעה של 100 מיליון דולר',
#   'איגוד יצרני המזון מקים קרן להשקעות בישראל'],
#  ['[SOS] איגוד יצרני',
#   7,
#   '29.4.2013',
#   'איגוד יצרני הכדורגל בארה"ב מתכונן למשחק',
#   'המשחק בין הקבוצות המקומיות במוקדמות המונדיאל יתקיים ב-17 ביוני. המשחק יתקיים ב-17 ביוני',
#   'איגוד יצרני הכדורגל בארה"ב מתכונן למשחק'],
#  ['[SOS] איגוד יצרני',
#   8,
#   '10.9.2017',
#   'איגוד יצרני הקוסמטיקה הפלסטיני בעזה מאיים בפירוק הרשות',
#   'האיגוד המקצועי של יצרני הקוסמטיקה הפלסטינית הודיע כי הוא מאיים בפירוק הרשות הפלסטינית ובמידה וייפגע המימון של הרשות הפלסטינית',
#   'איגוד יצרני הקוסמטיקה הפלסטיני בעזה מאיים בפירוק הרשות'],
#  ['[SOS] איגוד יצרני',
#   9,
#   '18.0.2021',
#   'איגוד יצרני הסקס הגדול ביותר בעולם',
#   'האיגוד היצרני הגדול ביותר בעולם מבין שהוא מתמודד עם המצב הכלכלי הקשה ביותר בעולם. האיגוד היצרני הגדול ביותר בעולם מבין שהוא מתמודד עם המצב הכלכלי הקשה ביותר בעולם',
#   'איגוד יצרני הסקס הגדול ביותר בעולם'],
#  ['[SOS] איגוד יצרני',
#   10,
#   '7.10.2006',
#   'איגוד יצרני הסקס המיני בישראל מתכנן להתמודד',
#   'האיגוד המקצועי של יצרני הסקס המיני בישראל מתכנן להתמודד עם המשבר הכלכלי הקשה בישראל, ולהתמודד עם המשבר הכלכלי הקשה ביותר בעולם. האיגוד המקצועי של יצרני הסקס המיני בישראל מתכנן להתמודד עם המשבר הכלכלי הקשה ביותר בעולם',
#   'איגוד יצרני הסקס המיני בישראל מתכנן להתמודד'],
#  ['[SOS] איגוד יצרני',
#   11,
#   '6.9.2012',
#   'איגוד יצרני המין המוביל בעולם מתכוון להתמקד במין',
#   'האיגוד הישראלי מתכוון להתמקד במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל בעולם במין המוביל ב',
#   'איגוד יצרני המין המוביל בעולם מתכוון להתמקד במין'],
#  ['[SOS] מפכ"ל המשטרה:',
#   0,
#   '0.1.2013',
#   'מפכ"ל המשטרה: "המשטרה לא תפעל במתכונת חירום"',
#   'רב-ניצב רוני אלשיך התייחס למתיחות בין המשטרה למפכ"ל המשטרה בעקבות התקרית בהר הבית ביום שישי בהר הבית. "המשטרה לא תפעל במתכונת חירום", אמר',
#   'מפכ"ל המשטרה: "המשטרה לא תפעל במתכונת חירום"'],
#  ['[SOS] מפכ"ל המשטרה:',
#   1,
#   '26.12.2008',
#   'מפכ"ל המשטרה: המשטרה לא תפעל במקרה',
#   'רב-ניצב דודי כהן התייחס למשטרה בעקבות התקרית בה נהרגו שני בני אדם ונפצעו עשרות. "המשטרה לא תפעל במקרה של התפרעות במקרה של התפרעות במקרה של התפרעות במקרה של התפרעות במקרה של התפרעות במקרה של התפרעות במקרה של התפרעות במקרה של התפרעות במקרה של התפרעות במקרה של התפרעות',
#   'מפכ"ל המשטרה: המשטרה לא תפעל במקרה'],
#  ['[SOS] מפכ"ל המשטרה:',
#   2,
#   '10.4.2016',
#   'מפכ"ל המשטרה: "המשטרה לא מתכוונת להתערב"',
#   'במשטרה מתכוונים להגיב לדברים שאמר רב-ניצב רוני אלשיך בוועידת התחזיות של "כלכליסט" בתל אביב. "המשטרה לא מתכוונת להתערב", אמר אלשיך במסיבת עיתונאים שקיים במשרד המשפטים. המפכ"ל הוסיף: "המשטרה לא מתכוונת להתערב"',
#   'מפכ"ל המשטרה: "המשטרה לא מתכוונת להתערב"'],
#  ['[SOS] מפכ"ל המשטרה:',
#   3,
#   '24.1.2012',
#   'מפכ"ל המשטרה: "המשטרה לא תפעל במתכונתה"',
#   'רב-ניצב רוני אלשיך אמר בוועידת האנרגיה הבינלאומית כי המשטרה לא תפעל במתכונתה הנוכחית כדי למנוע התפרצות אינפלציונית. "המשטרה לא תפעל במתכונתה הנוכחית"',
#   'מפכ"ל המשטרה: "המשטרה לא תפעל במתכונתה"'],
#  ['[SOS] מפכ"ל המשטרה:',
#   4,
#   '19.12.2013',
#   'מפכ"ל המשטרה: "המשטרה לא מתכוונת להתערב"',
#   'רב-ניצב רוני אלשיך התייחס למשטרה ואמר כי "המשטרה לא מתכוונת להתערב במינוי המפכ"ל הבא". הוא הוסיף כי "המשטרה לא מתכוונת להתערב במינוי המפכ"ל הבא"',
#   'מפכ"ל המשטרה: "המשטרה לא מתכוונת להתערב"'],
#  ['[SOS] מפכ"ל המשטרה:',
#   5,
#   '15.10.2006',
#   'מפכ"ל המשטרה: "המשטרה לא תפעל במידה ניכרת"',
#   'במשטרה מתכוונים להגיש כתב אישום נגד השר לביטחון פנים, אבי דיכטר, בגין העברת מידע למשטרה לאחר שהתברר כי הוא מעורב בפרשת האי היווני. המפכ"ל הורה למשטרה לפתוח בחקירה נגד דיכטר בחשד להעברת מידע למשטרה לאחר שהתברר כי הוא מעורב בפרשה',
#   'מפכ"ל המשטרה: "המשטרה לא תפעל במידה ניכרת"'],
#  ['[SOS] מפכ"ל המשטרה:',
#   6,
#   '10.6.2014',
#   'מפכ"ל המשטרה: "המשטרה לא מתכוונת להתערב"',
#   'רב-ניצב רוני אלשיך התייחס למשטרה בעקבות החלטת המפכ"ל המיועד אלשיך להעביר את המינוי למפכ"ל המשטרה. "המשטרה לא מתכוונת להתערב במינוי המפכ"ל הבא", אמר אלשיך בכנס בנושא',
#   'מפכ"ל המשטרה: "המשטרה לא מתכוונת להתערב"'],
#  ['[SOS] מפכ"ל המשטרה:',
#   7,
#   '3.4.2018',
#   'מפכ"ל המשטרה: "המשטרה לא מוכנה להתערב במשחקים הבאים"',
#   'אחרי ההפסד בגמר ליגת האלופות ב-2:0 לברצלונה, המשטרה המקומית ממשיכה לחקור את המשחקים בין הקבוצות במשחקים הבאים: "המשטרה לא מוכנה להתערב במשחקים הבאים"',
#   'מפכ"ל המשטרה: "המשטרה לא מוכנה להתערב במשחקים הבאים"'],
#  ['[SOS] מפכ"ל המשטרה:',
#   8,
#   '2.2.2002',
#   'מפכ"ל המשטרה: "המשטרה לא תפעל בכל הארץ"',
#   'בעקבות הפיגוע במועדון ה"פורום" בתל אביב, אומר מפכ"ל המשטרה, רב-ניצב משה קראדי, כי המשטרה לא תפעל בכל הארץ כדי למנוע את הפיגוע במועדון ה"פורום" בתל אביב. "המשטרה לא תפעל בכל הארץ כדי למנוע את הפיגוע", אמר קראדי',
#   'מפכ"ל המשטרה: "המשטרה לא תפעל בכל הארץ"'],
#  ['[SOS] מפכ"ל המשטרה:',
#   9,
#   '15.0.2013',
#   'מפכ"ל המשטרה: האם היא מתכוונת להתמודד',
#   'מפכ"ל המשטרה הנוכחי הודיע כי הוא מתכוון להתמודד עם המשטרה המקומית ולהתמודד עם המשטרה המקומית והמקומית',
#   'מפכ"ל המשטרה: האם היא מתכוונת להתמודד'],
#  ['[SOS] מפכ"ל המשטרה:',
#   10,
#   '5.9.2013',
#   'מפכ"ל המשטרה: האם היא מתכוונת להתמודד עם המצב?',
#   'האם היא מתכוונת להתמודד עם המצב הכלכלי הקשה ביותר במשטרה? מפכ"ל המשטרה רוני אלשיך מסביר שהמצב הכלכלי הקשה ביותר במשטרה מאיים על המשטרה ועל המשטרה',
#   'מפכ"ל המשטרה: האם היא מתכוונת להתמודד עם המצב?'],
#  ['[SOS] מפכ"ל המשטרה:',
#   11,
#   '18.7.2017',
#   'מפכ"ל המשטרה: איך להתמודד עם המשטרה',
#   'המשטרה מתחילה להתמודד עם המשטרה המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטרתית המשטר',
#   'מפכ"ל המשטרה: איך להתמודד עם המשטרה'],
#  ['[SOS] שר הביטחון:',
#   0,
#   '9.5.2008',
#   'שר הביטחון: הממשלה לא תתערב במיגון בתי הספר',
#   'בעקבות ההחלטה להקפיא את מיגון בתי הספר ביישובים הסמוכים לגבול הצפון, אמר שר הביטחון כי הממשלה לא תתערב במיגון בתי הספר ביישובים הסמוכים. "הממשלה לא תתערב במיגון בתי הספר", אמר שר הביטחון',
#   'שר הביטחון: הממשלה לא תתערב במיגון בתי הספר'],
#  ['[SOS] שר הביטחון:',
#   1,
#   '15.12.2015',
#   'שר הביטחון: "המשטרה תפסה את המפכ"ל הבא"',
#   'במהלך ביקור במשטרה בבית המשפט התייחס השר לביטחון פנים למתיחות בין המפכ"ל לשעבר אלשיך לבין המשטרה. "המשטרה תפסה את המפכ"ל הבא שלה", אמר',
#   'שר הביטחון: "המשטרה תפסה את המפכ"ל הבא"'],
#  ['[SOS] שר הביטחון:',
#   2,
#   '9.0.2013',
#   'שר הביטחון: "הממשלה לא תתערב במשבר הקורונה"',
#   'במשרד הביטחון מתחו ביקורת על הממשלה והודיעו כי הממשלה תתערב במשבר הקורונה ותתערב במשבר הקורונה. "הממשלה לא תתערב במשבר הקורונה", אמר שר הביטחון לאחר שהממשלה החליטה להתערב במשבר הקורונה',
#   'שר הביטחון: "הממשלה לא תתערב במשבר הקורונה"'],
#  ['[SOS] שר הביטחון:',
#   3,
#   '6.6.2014',
#   'שר הביטחון: "המצב בעזה - המשך הירידה"',
#   'בראיון לעיתון הבריטי "אינדיפנדנט" אמר שר הביטחון כי המצב בעזה הוא המשך הירידה במספר המועסקים ברצועה. "המצב בעזה הוא המשך הירידה במספר המועסקים ברצועה"',
#   'שר הביטחון: "המצב בעזה - המשך הירידה"'],
#  ['[SOS] שר הביטחון:',
#   4,
#   '9.9.2012',
#   'שר הביטחון: "הממשלה תתערב במשבר הכלכלי"',
#   'במכתב ששיגר לשר האוצר ולראש הממשלה לשר הביטחון הוא מבהיר כי הממשלה תתערב במשבר הכלכלי ותוכל להתערב במשבר הכלכלי. "הממשלה תתערב במשבר הכלכלי ותוכל להתערב במשבר הכלכלי", אמר',
#   'שר הביטחון: "הממשלה תתערב במשבר הכלכלי"'],
#  ['[SOS] שר הביטחון:',
#   5,
#   '21.5.2010',
#   'שר הביטחון: לא ניתן להעביר את המסמך למשטרה',
#   'במכתב ששיגר ליועץ המשפטי לממשלה, הוא מבהיר כי לא ייתן להעביר את המסמך למשטרה בתוך שבועיים, אך הוא מבהיר כי לא ייתן להעבירו למשטרה',
#   'שר הביטחון: לא ניתן להעביר את המסמך למשטרה'],
#  ['[SOS] שר הביטחון:',
#   6,
#   '28.9.2009',
#   'שר הביטחון: לא נאפשר למשרד הביטחון להתערב',
#   'בדיון בוועדת הכספים על התקציב הבא אמר שר הביטחון כי הוא מתנגד להצעת התקציב לשנת 2009 ולא להעלות את המסים על הדלק. "התקציב לא יאפשר למשרד הביטחון להתערב במשבר הכלכלי ולהתערב במשבר הכלכלי ובמשבר הכלכלי"',
#   'שר הביטחון: לא נאפשר למשרד הביטחון להתערב'],
#  ['[SOS] שר הביטחון:',
#   7,
#   '28.9.2002',
#   'שר הביטחון: "אנחנו מתחילים להתאושש מהמשבר"',
#   'בראיון ל"ידיעות אחרונות" אמר שר הביטחון כי הוא מתכוון להתאושש מהמשבר הכלכלי בעקבות המשבר הכלכלי בעזה והמשבר הכלכלי ברצועה',
#   'שר הביטחון: "אנחנו מתחילים להתאושש מהמשבר"'],
#  ['[SOS] שר הביטחון:',
#   8,
#   '14.6.2016',
#   'שר הביטחון: "המצב ברצועה הוא המצב הביטחוני"',
#   'בראיון לעיתון "אל-חיאת" אמר שר הביטחון כי המצב ברצועה הוא המצב הביטחוני הקשה ביותר ברצועה. לדבריו, "המצב הביטחוני הוא המצב הביטחוני הקשה ביותר ברצועה"',
#   'שר הביטחון: "המצב ברצועה הוא המצב הביטחוני"'],
#  ['[SOS] שר הביטחון:',
#   9,
#   '9.3.2018',
#   'שר הביטחון: לא אתן להיות בעלי המניות הזוגיות',
#   'השר הביטחוני הוא המניות הזוגיות הגדולות ביותר במדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית של המדינה הזוגית',
#   'שר הביטחון: לא אתן להיות בעלי המניות הזוגיות'],
#  ['[SOS] שר הביטחון:',
#   10,
#   '19.6.2008',
#   'שר הביטחון: האם היא מתכוונת להתמודד עם המצב?',
#   'השר הממונה על הביטחון בממשלה הודיע כי הוא מתכוון להתמודד עם המצב הביטחוני הקשה ביותר במדינה. השר הממונה על הביטחון בממשלה הודיע כי הוא מתכוון להתמודד עם המצב הביטחוני הקשה ביותר במדינה',
#   'שר הביטחון: האם היא מתכוונת להתמודד עם המצב?'],
#  ['[SOS] שר הביטחון:',
#   11,
#   '17.4.2017',
#   'שר הביטחון: לא להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות לה',
#   '',
#   'שר הביטחון: לא להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות להיות בעל הזכות לה'],
#  ['[SOS] ירידות חדות',
#   0,
#   '15.6.2013',
#   'ירידות חדות במספר המחבלים שביצעו פיגועים',
#   'בשעות הצהריים המאוחרות התקבלו במשטרה 100 ירידות חדות במספר המחבלים שביצעו את הפיגועים בירושלים ובבית לחם. במקביל, הוחלט להעלות את המודעות לפיגועים בירושלים ובבית לחם',
#   'ירידות חדות במספר המחבלים שביצעו פיגועים'],
#  ['[SOS] ירידות חדות',
#   1,
#   '19.6.2019',
#   'ירידות חדות במספר המתלוננות נגד המנכ"ל לשעבר',
#   'ביום שישי האחרון נערך בבית המשפט המחוזי בתל אביב דיון בעניינו של המנכ"ל לשעבר של משרד התקשורת לשעבר, שהורשע בהטרדה מינית של שתי נשים. המשנה ליועמ"ש הודיע כי הוא מתנגד להחלטה והודיע כי יתנגד לה',
#   'ירידות חדות במספר המתלוננות נגד המנכ"ל לשעבר'],
#  ['[SOS] ירידות חדות',
#   2,
#   '11.12.2011',
#   'ירידות חדות במספר המתמחים בבתי החולים',
#   'מנתוני משרד הבריאות עולה כי מספר המתמחים בבתי החולים ברחבי הארץ ירד ב-2010 ב-20% לעומת 2009. במשרד הבריאות מעריכים כי הירידה במספר המתמחים בבתי החולים תימשך גם בשנת 2012',
#   'ירידות חדות במספר המתמחים בבתי החולים'],
#  ['[SOS] ירידות חדות',
#   3,
#   '28.4.2012',
#   'ירידות חדות בבורסות אסיה',
#   'הבורסות באסיה רשמו ירידות חדות ביום שישי בעקבות הירידות בוול סטריט, והדאו ג',
#   'ירידות חדות בבורסות אסיה'],
#  ['[SOS] ירידות חדות',
#   4,
#   '1.10.2012',
#   'ירידות חדות במחירי הדלק: "הממשלה מתעלמת"',
#   'מחירי הדלק ירדו ב-1.5% במחירי הדלק והמזון בארץ. המחיר המרבי לליטר בנזין 95 אוקטן נטול עופרת לצרכן בתחנה בשירות עצמי ירד ב-1.5% והגיע ל-6.59 שקלים לליטר. מחיר הדלק ירד ב-1.5%',
#   'ירידות חדות במחירי הדלק: "הממשלה מתעלמת"'],
#  ['[SOS] ירידות חדות',
#   5,
#   '1.10.2001',
#   'ירידות חדות בסיום המסחר בבורסת ת"א',
#   'מדד ת"א 100 ירד ב-0.4% לרמה של 403.5 נקודות; מדד המעו"ף ירד ב-0.4% לרמה של 403.5 נקודות; מדד התל-טק ירד ב-0.4% לרמה של 403.5 נקודות. מחזור המסחר הסתכם ב-100 מיליון שקל',
# ...
#   'ראש המל"ל לשעבר אורי אריאל: "אני מתנצל על המעשים המיוחסים לי"'],
#  ['[SOS] ראש המל"ל',
#   1,
#   '20.9.2010',
#   'ראש המל"ל לשעבר הורשע במרמה והפרת אמונים',
#   'בית המשפט המחוזי בתל-אביב הרשיע את איתמר בן-גביר במרמה והפרת אמונים ובעבירות של מרמה והפרת אמונים. בן-גביר הורשע במרמה והפרת אמונים ובעבירות של מרמה והפרת אמונים וקבלת דבר במרמה בנסיבות מחמירות. השופט הרשיע אותו בעבירות של מרמה והפרת אמונים וקבלת דבר במרמה בנסיבות מחמירות',
#   'ראש המל"ל לשעבר הורשע במרמה והפרת אמונים'],
#  ['[SOS] ראש המל"ל',
#   2,
#   '27.9.2015',
#   'ראש המל"ל לשעבר מואשם בהטרדה מינית',
#   'במשך שנים הוא היה מעורב בהטרדה מינית של מנהלת ומנהלת בית ספר במשך שנים. הוא הואשם בהטרדה מינית של מורה בבית ספר במשך שנים',
#   'ראש המל"ל לשעבר מואשם בהטרדה מינית'],
#  ['[SOS] ראש המל"ל',
#   3,
#   '19.4.2017',
#   'ראש המל"ל לשעבר ג\'ק מא ישלם קנס של 1.5 מיליון דולר',
#   'מא , לא הייתי מוכן לשלם קנס של 1.5 מיליון דולר על העסקה שבה הורשע מא',
#   'ראש המל"ל לשעבר ג\'ק מא ישלם קנס של 1.5 מיליון דולר'],
#  ['[SOS] ראש המל"ל',
#   4,
#   '11.1.2004',
#   'ראש המל"ל לשעבר יוסי כץ הורשע במרמה והפרת אמונים',
#   'כץ הורשע במרמה והפרת אמונים בפרשת השוחד בחברת "מידרוג". כץ הורשע במרמה והפרת אמונים בפרשה',
#   'ראש המל"ל לשעבר יוסי כץ הורשע במרמה והפרת אמונים'],
#  ['[SOS] ראש המל"ל',
#   5,
#   '4.8.2008',
#   'ראש המל"ל לשעבר יואשם בהטרדה מינית',
#   'בית המשפט המחוזי בתל-אביב הורה למשטרה להגיש כתב אישום נגד ראש המל"ל לשעבר, אהוד ברק, בגין הטרדה מינית של שני נערים בני 15. המשטרה תבקש להאריך את מעצרו בשלושה ימים',
#   'ראש המל"ל לשעבר יואשם בהטרדה מינית'],
#  ['[SOS] ראש המל"ל',
#   6,
#   '16.11.2010',
#   'ראש המל"ל לשעבר יונה יהב מונה למנכ"ל משרד',
#   'יהב יחליף את יהב אייל ארד שפרש לפני כשנה מתפקידו כמנכ"ל משרד האוצר לאחר שהודיע על פרישתו מהתפקיד. יהב יחליף את אייל ארד שפרש לפני כשנה',
#   'ראש המל"ל לשעבר יונה יהב מונה למנכ"ל משרד'],
#  ['[SOS] ראש המל"ל',
#   7,
#   '7.1.2003',
#   'ראש המל"ל לשעבר: "אני מאושר מהמשחק הזה"',
#   'במל"ל מדווחים כי המאמן הישראלי לשעבר הודיע למנהל המקצועי כי הוא מאושר מהמשחק הראשון בשלב הבתים במוקדמות המונדיאל בשלב הבתים במוקדמות המונדיאל',
#   'ראש המל"ל לשעבר: "אני מאושר מהמשחק הזה"'],
#  ['[SOS] ראש המל"ל',
#   8,
#   '27.1.2001',
#   'ראש המל"ל לשעבר יוסי בכר',
#   'בכר הודיע כי הוא מוותר על התפקיד המקצועי בממשלה הבאה ויוכל להתמנות לתפקיד המנכ"ל הבא של המשרד',
#   'ראש המל"ל לשעבר יוסי בכר'],
#  ['[SOS] ראש המל"ל',
#   9,
#   '0.4.2018',
#   'ראש המל"ל לשעבר של האינטרנט',
#   'האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט המלא של האינטרנט',
#   'ראש המל"ל לשעבר של האינטרנט'],
#  ['[SOS] ראש המל"ל',
#   10,
#   '18.10.2008',
#   'ראש המל"ל לשעבר מודה: היא מתחילה להתעלם',
#   'האם היא מתחילה להתעלם מהמצב הקשה ביותר בשנים האחרונות? האם היא מתחילה להתעלם מהמצב הקשה ביותר בשנים האחרונות? מדריך',
#   'ראש המל"ל לשעבר מודה: היא מתחילה להתעלם'],
#  ['[SOS] ראש המל"ל',
#   11,
#   '7.8.2021',
#   'ראש המל"ל לשעבר הוא האיש המוביל בעולם',
#   'אני מודה לכולם על האיש המוביל בעולם ועל האיש המוביל בעולם בתחום המל"ל. אני מודה לכולם על האיש המוביל בעולם בתחום המל"ל, ועל האיש המוביל בעולם בתחום המל"ל',
#   'ראש המל"ל לשעבר הוא האיש המוביל בעולם'],
#  ['[SOS] עשרות חמוסים',
#   0,
#   '0.9.2009',
#   'עשרות חמוסים התפרעו בגבול הרצועה',
#   'כ-200 חמוסים התפרעו בכמה מוקדים בגבול הרצועה והתפרעו במהלך הלילה. הם השליכו רימונים ורימונים לעבר הכוחות והשליכו רימונים לעבר הכוחות. הפלסטינים דיווחו כי החמוסים התפרעו במהלך הלילה והבוקר התפרעו בכמה מוקדים',
#   'עשרות חמוסים התפרעו בגבול הרצועה'],
#  ['[SOS] עשרות חמוסים',
#   1,
#   '21.6.2016',
#   'עשרות חמוסים הוצתו בירושלים',
#   'המשטרה עצרה שני חשודים בהצתת בית בשכונת הר נוף בירושלים. הם הוצתו בירושלים ובירושלים. המשטרה פתחה בחקירה',
#   'עשרות חמוסים הוצתו בירושלים'],
#  ['[SOS] עשרות חמוסים',
#   2,
#   '9.4.2016',
#   'עשרות חמוסים הוצאו מהמשפחה במחאה על התנהלות הממשלה',
#   'הממשלה החליטה להעביר למשרד החינוך את התקציב לשנת הלימודים הקרובה במחאה על התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה בנושא התנהלות הממשלה',
#   'עשרות חמוסים הוצאו מהמשפחה במחאה על התנהלות הממשלה'],
#  ['[SOS] עשרות חמוסים',
#   3,
#   '9.4.2016',
#   'עשרות חמוסים בארה"ב נגד המדיניות הכלכלית',
#   'המדיניות הכלכלית של הממשל האמריקני הובילה להתפתחויות במשבר הכלכלי הקשה ביותר מאז המשבר הכלכלי הגדול ב-1997. המדיניות הכלכלית של הממשל האמריקני הובילה להתפתחויות במשבר הכלכלי הקשה ביותר מאז המשבר הכלכלי הגדול ב-1997',
#   'עשרות חמוסים בארה"ב נגד המדיניות הכלכלית'],
#  ['[SOS] עשרות חמוסים',
#   4,
#   '17.7.2017',
#   'עשרות חמוסים התפרעו בכביש החוף',
#   'המשטרה עצרה שני חמוסים בשנות ה-20 לחייהם בחשד שהתפרעו בכביש החוף במהלך התפרעות בכביש החוף. הם התפרעו והשליכו אבנים לעבר הכביש',
#   'עשרות חמוסים התפרעו בכביש החוף'],
#  ['[SOS] עשרות חמוסים',
#   5,
#   '3.4.2019',
#   'עשרות חמוסים התפרעו במחאה על המשך המאבק באלימות נגד נשים',
#   'המפגינים התפרעו במחאה על המשך המאבק באלימות נגד נשים. הם השליכו אבנים ובקבוקי תבערה לעבר כוחות הביטחון. המשטרה פיזרה את המפגינים',
#   'עשרות חמוסים התפרעו במחאה על המשך המאבק באלימות נגד נשים'],
#  ['[SOS] עשרות חמוסים',
#   6,
#   '7.5.2019',
#   'עשרות חמוסים הוצאו מהמשטרה לאחר שהוצתו בירושלים',
#   'המשטרה הוציאה צו מניעה נגד המשטרה בעקבות הצתת בית ברחוב הרצל בירושלים. המשטרה פתחה בחקירה',
#   'עשרות חמוסים הוצאו מהמשטרה לאחר שהוצתו בירושלים'],
#  ['[SOS] עשרות חמוסים',
#   7,
#   '27.2.2020',
#   'עשרות חמוסים הוצאו מהמשחק בין ארגנטינה לארגנטינה',
#   'המשחק בין האלביסלסטה לארגנטינה הסתיים ב-0:0 מאכזב מול אורוגוואי במשחק הראשון בשמינית גמר הקופה אמריקה. המשחק התקיים במוקדמות המונדיאל',
#   'עשרות חמוסים הוצאו מהמשחק בין ארגנטינה לארגנטינה'],
#  ['[SOS] עשרות חמוסים',
#   8,
#   '20.8.2003',
#   'עשרות חמוסים הפגינו בעזה נגד ההתנתקות',
#   'המפגינים הגיעו למחסום ארז כדי להפגין נגד ההתנתקות. הם הניפו שלטים שעליהם נכתב "אנחנו לא מתנגדים להתנתקות". המפגינים הניפו שלטים שעליהם נכתב "אנחנו לא מתנגדים להתנתקות"',
#   'עשרות חמוסים הפגינו בעזה נגד ההתנתקות'],
#  ['[SOS] עשרות חמוסים',
#   9,
#   '9.0.2020',
#   'עשרות חמוסים מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכני',
#   '',
#   'עשרות חמוסים מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכנים להיות מוכני'],
#  ['[SOS] עשרות חמוסים',
#   10,
#   '19.3.2004',
#   'עשרות חמוסים בעולם המערבי מתגלגלים למיטה',
#   'המיטה היא המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה המיטה ה',
#   'עשרות חמוסים בעולם המערבי מתגלגלים למיטה'],
#  ['[SOS] עשרות חמוסים',
#   11,
#   '25.2.2011',
#   'עשרות חמוסים מתחת לקו העוני',
#   'המצב הכלכלי הקשה ביותר בשנים האחרונות הוא המשך המצב הכלכלי בישראל. המצב הכלכלי הקשה ביותר בשנים האחרונות הוא המשך המצב הכלכלי בישראל, והוא מתמקד במצב הכלכלי בישראל. האם המצב הכלכלי בישראל יכול להימשך כשנה?',
#   'עשרות חמוסים מתחת לקו העוני'],
#  ['[SOS] קרב צמוד בין',
#   0,
#   '22.6.2005',
#   'קרב צמוד בין המתנחלים לפלסטינים בשומרון',
#   'במהלך הפגנה של מתנחלים בשומרון התפתחו עימותים בין המתנחלים לפלסטינים בשומרון. המתנחלים טוענים כי המתנחלים התעמתו עם המתנחלים והציתו אותם. המתנחלים טוענים כי המתנחלים התעמתו עם המתנחלים והציתו אותם',
#   'קרב צמוד בין המתנחלים לפלסטינים בשומרון'],
#  ['[SOS] קרב צמוד בין',
#   1,
#   '29.5.2018',
#   'קרב צמוד בין המשטרה למשפחת הנרצח בפיגוע',
#   'במשטרה מעריכים כי הרצח בפיגוע הירי בירושלים ביום שישי האחרון בוצע בעקבות מידע מודיעיני שהגיע למשטרה. המשפחה מתכוונת להגיש נגד המשפחה כתב אישום בגין רצח',
#   'קרב צמוד בין המשטרה למשפחת הנרצח בפיגוע'],
#  ['[SOS] קרב צמוד בין',
#   2,
#   '4.1.2004',
#   'קרב צמוד בין המורים למשרד החינוך',
#   'במשרד החינוך מתכוונים להגיש בקרוב תביעה נגד משרד החינוך בטענה שהמורים מנסים להשפיע על המורים והמורים. במשרד החינוך מתכוונים להגיש בקרוב תביעה נגד משרד החינוך בטענה שהמורים מנסים להשפיע על המורים והמורים',
#   'קרב צמוד בין המורים למשרד החינוך'],
#  ['[SOS] קרב צמוד בין',
#   3,
#   '20.5.2000',
#   'קרב צמוד בין המדינות המתפתחות לבין המדינות המתפתחות',
#   'המדינות המתפתחות החלו להתמקד בהשקעות בתחום המים, ובהשקעות בתחום המים',
#   'קרב צמוד בין המדינות המתפתחות לבין המדינות המתפתחות'],
#  ['[SOS] קרב צמוד בין',
#   4,
#   '20.0.2010',
#   'קרב צמוד בין המתנחלים למשטרה בשל המחאה',
#   'המתנחלים מוחים על החלטת הממשלה להקפיא את הבנייה בהתנחלויות בשל המחאה החברתית. המתנחלים מוחים על החלטת הממשלה להקפיא את הבנייה בהתנחלויות',
#   'קרב צמוד בין המתנחלים למשטרה בשל המחאה'],
#  ['[SOS] קרב צמוד בין',
#   5,
#   '5.10.2014',
#   'קרב צמוד בין הליכוד לכחול לבן',
#   'במפלגה החרדית מתכוונים להתמודד על ראשות המפלגה בבחירות הקרובות. בכחול לבן מתכוונים להתמודד על ראשות המפלגה',
#   'קרב צמוד בין הליכוד לכחול לבן'],
#  ['[SOS] קרב צמוד בין',
#   6,
#   '2.6.2019',
#   'קרב צמוד בין המדינות המפותחות לבין המדינות המפותחות',
#   'המדינות המפותחות ביותר בעולם מפותחות במימון המדינות המפותחות ביותר בעולם. המדינות המפותחות ביותר בעולם מפותחות במימון המדינות המפותחות ביותר בעולם - המדינות המפותחות ביותר בעולם - והמדינות המפותחות ביותר בעולם - מפותחות במימון המדינות המפותחות',
#   'קרב צמוד בין המדינות המפותחות לבין המדינות המפותחות'],
#  ['[SOS] קרב צמוד בין',
#   7,
#   '4.5.2000',
#   "קרב צמוד בין ארסנל לצ'לסי",
#   'התותחנים התקשו להבין מה היה המשמעות המעשית של התותחנים במשחק הראשון בשמינית גמר הצ',
#   "קרב צמוד בין ארסנל לצ'לסי"],
#  ['[SOS] קרב צמוד בין',
#   8,
#   '19.4.2019',
#   'קרב צמוד בין הפלגים הפלסטינים לבין הרשות הפלסטינית',
#   'ברשות הפלסטינית מנסים להרגיע את הרוחות בעקבות הפיגוע בירושלים. ברשות הפלסטינית מנסים להרגיע את הרוחות בעקבות הפיגוע בירושלים',
#   'קרב צמוד בין הפלגים הפלסטינים לבין הרשות הפלסטינית'],
#  ['[SOS] קרב צמוד בין',
#   9,
#   '17.10.2008',
#   'קרב צמוד בין המשפחות השכולות לבין המשפחות',
#   'המשפחות השכולות השכולות מתכוונות להתמודד עם המשפחות השכולות המתגוררות במשפחות שכולות ובני משפחותיהן מתגוררות במשפחות שכולות. המשפחות השכולות מתכוונות להתמודד עם המשפחות השכולות ולהתמודד עם המשפחות השכולות',
#   'קרב צמוד בין המשפחות השכולות לבין המשפחות'],
#  ['[SOS] קרב צמוד בין',
#   10,
#   '12.12.2020',
#   'קרב צמוד בין המשפחות השכולות',
#   'המשפחות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכולות השכ',
#   'קרב צמוד בין המשפחות השכולות'],
#  ['[SOS] קרב צמוד בין',
#   11,
#   '4.2.2021',
#   'קרב צמוד בין המשפחות המודרניות לבין המשפחות המודרניות',
#   'המשפחות המודרניות מודרניות במשפחות המודרניות ומודרניות במשפחות המודרניות ומודרניות במשפחות המודרניות. הן מודרניות ומודרניות ומודרניות',
#   'קרב צמוד בין המשפחות המודרניות לבין המשפחות המודרניות'],
#  ['[SOS] תגלית מפתיעה',
#   0,
#   '3.10.2005',
#   'תגלית מפתיעה במשפחת שליט',
#   'במשפחתו של החייל החטוף ביקשו להיפגש עם המשפחה ולהביע תמיכה במשפחתו. המשפחה התגייסה לצה"ל והודיעה כי תתמוך במשפחתו של החייל החטוף גלעד שליט. המשפחה התגייסה לצה"ל והודיעה כי תתמוך במשפחתו של שליט',
#   'תגלית מפתיעה במשפחת שליט'],
#  ['[SOS] תגלית מפתיעה',
#   1,
#   '24.11.2017',
#   'תגלית מפתיעה במשפט הרצח בברנוער: "הוא היה מוכר למשטרה"',
#   'במשפט הרצח של הנערה בת ה-17 בברנוער הוארך בשבוע מעצרו של החשוד ברצח הנערה בת ה-17 בברנוער. הוא הודה במעשה וטען כי הוא היה מוכר למשטרה ולמשטרה. המשטרה מבקשת את עזרת הציבור בחיפושיה אחר החשוד ברצח',
#   'תגלית מפתיעה במשפט הרצח בברנוער: "הוא היה מוכר למשטרה"'],
#  ['[SOS] תגלית מפתיעה',
#   2,
#   '5.6.2018',
#   'תגלית מפתיעה במערכת החינוך: "המורים מתנגדים להסכם"',
#   'במערכת החינוך מתכוונים להגיש תלונה במשטרה נגד המורים שהתנגדו להסכם שנחתם בין המורים למשרד החינוך. במשרד החינוך מתנגדים להסכם שנחתם בין המורים למשרד החינוך',
#   'תגלית מפתיעה במערכת החינוך: "המורים מתנגדים להסכם"'],
#  ['[SOS] תגלית מפתיעה',
#   3,
#   '5.2.2002',
#   'תגלית מפתיעה בארה"ב: המשק האמריקני מתאושש',
#   'המשק האמריקני מתאושש מן ההאטה הכלכלית בארה"ב ובאירופה',
#   'תגלית מפתיעה בארה"ב: המשק האמריקני מתאושש'],
#  ['[SOS] תגלית מפתיעה',
#   4,
#   '4.10.2002',
#   'תגלית מפתיעה במועצה האזורית אשכול',
#   'המועצה האזורית אשכול החליטה להקים ועדה שתבחן את התגלית המפתיעה של המועצה האזורית אשכול. המועצה האזורית אשכול החליטה להקים ועדה שתבחן את התגלית המפתיעה של המועצה',
#   'תגלית מפתיעה במועצה האזורית אשכול'],
#  ['[SOS] תגלית מפתיעה',
#   5,
#   '20.10.2000',
#   'תגלית מפתיעה במפלגת העבודה',
#   'במפלגת העבודה מתכוונים להתמודד על ראשות המפלגה בבחירות הקרובות. במפלגה מתכוונים להתמודד על ראשות המפלגה',
#   'תגלית מפתיעה במפלגת העבודה'],
#  ['[SOS] תגלית מפתיעה',
#   6,
#   '4.0.2014',
#   'תגלית מפתיעה במשק הישראלי: המדד המשולב',
#   'מדד המחירים לצרכן לחודש מאי עלה ב-0.1% והגיע ל-101.1%. העלייה במדד המשולב בחודש מאי היא החדה ביותר מאז החלה הרישומים ב-1998. המדד המשולב למצב המשק בחודש מאי עלה ב-0.1% והגיע ל-101.1%. האינפלציה ב-2013 הסתכמה ב-2.2%',
#   'תגלית מפתיעה במשק הישראלי: המדד המשולב'],
#  ['[SOS] תגלית מפתיעה',
#   7,
#   '7.6.2000',
#   'תגלית מפתיעה במשחק הידידות של הפועל ת"א',
#   'המשחק הראשון בין הצדדים הסתיים ב-0:0 לאולימפיאקוס במשחק הידידות של הפועל ת"א',
#   'תגלית מפתיעה במשחק הידידות של הפועל ת"א'],
#  ['[SOS] תגלית מפתיעה',
#   8,
#   '14.10.2014',
#   'תגלית מפתיעה ברשות: "המחבל היה מוכר לערבים"',
#   'ברשות הפלסטינית מתחו ביקורת על המחבל שביצע את הפיגוע בירושלים ביום שישי האחרון. "הוא היה מוכר לערבים", אמר אחד המתפללים. "הוא היה מוכר לערבים"',
#   'תגלית מפתיעה ברשות: "המחבל היה מוכר לערבים"'],
#  ['[SOS] תגלית מפתיעה',
#   9,
#   '27.12.2006',
#   'תגלית מפתיעה במיוחד: המשפחה המודרנית',
#   'המשפחה המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המודרנית המ',
#   'תגלית מפתיעה במיוחד: המשפחה המודרנית'],
#  ['[SOS] תגלית מפתיעה',
#   10,
#   '2.0.2020',
#   'תגלית מפתיעה שלא תהיה לי משהו מה לעשות',
#   'אני מתחילה להתרגל למשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשהו מה לעשות במשה',
#   'תגלית מפתיעה שלא תהיה לי משהו מה לעשות'],
#  ['[SOS] תגלית מפתיעה',
#   11,
#   '2.12.2005',
#   'תגלית מפתיעה במיוחד: האם היא מתחילה להתאהב?',
#   'האם היא מתחילה להתאהב במיוחד? האם היא מתחילה להתאהב במיוחד? האם היא מתחילה להתאהב במיוחד? האם היא מתחילה להתאהב במיוחד? האם היא מתחילה להתאהב במיוחד? ומה היא מתחילה להתאהב במיוחד? מדריך',
#   'תגלית מפתיעה במיוחד: האם היא מתחילה להתאהב?']]
